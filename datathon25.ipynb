# %% [markdown]
# # Goals
#
# 1. Predict the customer spending for the fourth quarter of the current year.
#
# 2. Classify the Accounts eligible for **Credit Line Increase without Risk**, **Accounts eligible for Credit Line Increase but has risk of potential defaults or fraud**, **No Credit Line Increase required** and **Non-Performing accounts that pose a high risk**.
#
# 3. For each of the account segments what would be a credit line increase that could be offered at individual account?
#
# ## Steps:
# 1. Analyze historical spending patterns using account data and non-monetary information.
# - Make plots showing amount spent by date
# - Focus on time from October through December
# 2. Predict the customer spending for the fourth quarter of the current year. Specifically, Using the recent last
# eight months of spending can we predict the customer spending for Q4 2025 (October to December
# 2025).
# - Make a linear regression model using variables of interest
# 3. Classify accounts in to segments that can help identify potential accounts that would need a credit line
# increase because of the predicted spending.
# - Credit limit - Amount spent; if spent > 90% of limit
# 4. Using risk factors overextension, fraud, or potential defaults, suggest the amount of credit line increase
# that could be given to an account.

# %% [markdown]
# Questions to ask:
# - Explain Open to Buy;
# - Random Number?
# - Old vs New Behavior Score?
# Negative Current Utiliz?

# %% [markdown]
# ## Variables of Interest
# 1. Behavior Score Old/New -- (Account Level Features)
# 2. Payment History -- (Card Holder Account)
# 3. overlimit_type_flag -- (Card Holder Account)
# 4. External_status_reason_code -- (Card Holder Account)
# 5. Nsf_count ie nonsufficient funds count last 12 months -- (Account Level Features)
# 6. Account Card type (Dual or PLCC) -- (Card Holder Account)
# 7. OTB (Open to Buy, )
# 8. Credit Score
# 9. Special Finance Charge? - Card Holder Account
# 10. Current Utiliz (current balance as percentage of current credit line)
#
# ## New Variables:
# - Sum of total spending between 10/2024 - 12/2024
# - Monthly sum of money spent
# - Calculate monthly credit limit
#
# ### For Predicting Q4 Spending
# - Sum of total spending between 10/2024 - 12/2024
# - Account Card Type

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import statsmodels.formula.api as smf 
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
import numpy as np
from sklearn.model_selection import train_test_split
from pandas.plotting import scatter_matrix

# %% [markdown]
# ### Reading in Files

# %%
df_account_dim = pd.read_csv("/Users/kaitlinbaggot/Desktop/datathon 2025/account_dim_20250325.csv")
df_account_dim
# Out:
#       current_account_nbr      client_id                      open_date  \
# 0        nTgalbpd5Rsol7CA    YCTHAA278DC  2020-07-17T00:00:00.000-04:00
# 1        xYaLrD9IvmbVl1PB    CCSP489PLCC  2024-07-24T00:00:00.000-04:00
# 2        JM78WNziiRWgmL8e   HGBHARRFT984  2024-05-05T00:00:00.000-04:00
# 3        bv4NLVhWTGCf8KgC       OSELW263  2024-07-28T00:00:00.000-04:00
# 4        nrXceQabYIHo31lp   HGBHARRFT984  2024-09-15T00:00:00.000-04:00
# ...                   ...            ...                            ...
# 18065    K8ixzIELRNtw1drn  YAUAPPLLDA934  2023-11-27T00:00:00.000-05:00
# 18066    CRIi94oT7Dddh2zu     TJX513PLCC  2023-09-11T00:00:00.000-04:00
# 18067    XiW0as5dJX6GJRi0    CCSP489PLCC  2023-12-03T00:00:00.000-05:00
# 18068    Xu1i4wqn776tFKU6    CMSSSNAO606  2023-07-27T00:00:00.000-04:00
# 18069    UU3UiLwIVVSikGPq    ARPPYALC768  2016-03-03T00:00:00.000-05:00
#
#                 card_activation_date card_activation_flag ebill_ind  \
# 0                                NaN                    8         E
# 1      2024-08-09T00:00:00.000-04:00                    0         E
# 2      2024-05-05T00:00:00.000-04:00                    0  \\\\\\""
# 3      2024-09-08T00:00:00.000-04:00                    0  \\\\\\""
# 4      2024-09-15T00:00:00.000-04:00                    0  \\\\\\""
# ...                              ...                  ...       ...
# 18065                            NaN                    7         E
# 18066  2023-09-11T00:00:00.000-04:00                    0  \\\\\\""
# 18067                            NaN                    7         E
# 18068  2025-01-20T00:00:00.000-05:00                    0         E
# 18069  2019-07-11T00:00:00.000-04:00                    0         L
#
#        date_in_collection  overlimit_type_flag payment_hist_1_12_mths  \
# 0                     NaN                    0           ZZZZZZIAZZZZ
# 1                     NaN                    0               IQIIIQIA
# 2                     NaN                    0            IIIQIQIIIIA
# 3                     NaN                    0                I1III1A
# 4                     NaN                    0               \\\\\\""
# ...                   ...                  ...                    ...
# 18065                 NaN                    0           ZZZZZQQQQQQQ
# 18066                 NaN                    0           ZZZZZZZZZZZZ
# 18067                 NaN                    0           ZZZIIIIIIIII
# 18068                 NaN                    0           Z0ZZZZIIAIQQ
# 18069                 NaN                    0           ZZZZZZZZZZZZ
#
#       payment_hist_13_24_mths employee_code  external_status_reason_code  \
# 0                ZZZZIIIQIIII           NaN                            0
# 1                    \\\\\\""           NaN                            0
# 2                    \\\\\\""           NaN                            0
# 3                    \\\\\\""           NaN                            0
# 4                    \\\\\\""           NaN                            0
# ...                       ...           ...                          ...
# 18065                    QQ#A           NaN                           35
# 18066                  ZZZZIA           NaN                           35
# 18067                    IIIA           NaN                           35
# 18068                 QQQIQIA           NaN                           46
# 18069                ZZZZZZZQ           NaN                            0
#
#        special_finance_charge_ind  pscc_ind  \
# 0                             NaN         0
# 1                             NaN         1
# 2                             NaN         0
# 3                             NaN         0
# 4                             NaN         0
# ...                           ...       ...
# 18065                         NaN         0
# 18066                         NaN         0
# 18067                         NaN         1
# 18068                         NaN         0
# 18069                         NaN         0
#
#                                ext_status_reason_cd_desc account_card_type
# 0                                                    NaN         DUAL CARD
# 1                                                    NaN         DUAL CARD
# 2                                                    NaN              PLCC
# 3                                                    NaN              PLCC
# 4                                                    NaN              PLCC
# ...                                                  ...               ...
# 18065  A35 Temporary Freeze - Customer may have lost ...         DUAL CARD
# 18066  A35 Temporary Freeze - Customer may have lost ...              PLCC
# 18067  A35 Temporary Freeze - Customer may have lost ...         DUAL CARD
# 18068           A46 Universal Fraud Team Potential Fraud              PLCC
# 18069                                                NaN              PLCC
#
# [18070 rows x 16 columns]

# %%
df_transactions = pd.read_csv("/Users/kaitlinbaggot/Desktop/datathon 2025/transaction_fact_20250325.csv")
df_transactions
# Out:
#        current_account_nbr transaction_type  transaction_code  \
# 0         X7jfKh6xrPAB8Tx6             SALE               253
# 1         yntD77AZDylS48Q4             SALE               253
# 2         LIJPI0sK28Pa7fX2             SALE               253
# 3         CMAr5Apxwdzpvoze             SALE               253
# 4         eJSfTCGPvJulGzd3             SALE               253
# ...                    ...              ...               ...
# 493331    ktpdvlbVRuywp2Po             SALE               253
# 493332    xwgOt4lvAHr517sa             SALE               253
# 493333    zp60CmOQNComnHDT             SALE               253
# 493334    8M5fnshTsgW9mW8Y          PAYMENT               271
# 493335    qT645tAyt7uDVJtL           RETURN               255
#
#        transaction_date  transaction_amt  payment_type  \
# 0            2024-06-05            15.78           NaN
# 1            2024-06-19            14.85           NaN
# 2            2024-06-26           136.16           NaN
# 3            2024-08-15             8.74           NaN
# 4            2024-08-17            26.65           NaN
# ...                 ...              ...           ...
# 493331       2025-03-07             3.99           NaN
# 493332       2024-07-27             6.13           NaN
# 493333       2025-02-04            15.62           NaN
# 493334       2025-02-05           100.00           NaN
# 493335       2025-02-14            44.14           NaN
#
#         transaction_return_cnt  transaction_sale_cnt  product_amt  \
# 0                            0                     1          NaN
# 1                            0                     1          NaN
# 2                            0                     1          NaN
# 3                            0                     1          NaN
# 4                            0                     1          NaN
# ...                        ...                   ...          ...
# 493331                       0                     1          NaN
# 493332                       0                     1          NaN
# 493333                       0                     1          NaN
# 493334                       0                     0          NaN
# 493335                       1                     0          NaN
#
#         product_qty  ...  first_purchase_ind adj_orgn_tran_dt curr_markup_fee  \
# 0               NaN  ...                   N              NaN             0.0
# 1               NaN  ...                   N              NaN             0.0
# 2               NaN  ...                   N              NaN             0.0
# 3               NaN  ...                   N              NaN             0.0
# 4               NaN  ...                   N              NaN             0.0
# ...             ...  ...                 ...              ...             ...
# 493331          NaN  ...                   N              NaN             0.0
# 493332          NaN  ...                   N              NaN             0.0
# 493333          NaN  ...                   N              NaN             0.0
# 493334          NaN  ...                   N              NaN             0.0
# 493335          NaN  ...                   N              NaN             0.0
#
#         fcr_amount  fcr_flag  fcr_rate_of_exchange  frgn_curr_code  \
# 0              NaN       NaN                   NaN             840
# 1              NaN       NaN                   NaN             840
# 2              NaN       NaN                   NaN             840
# 3              NaN       NaN                   NaN             840
# 4              NaN       NaN                   NaN             840
# ...            ...       ...                   ...             ...
# 493331         NaN       NaN                   NaN             840
# 493332         NaN       NaN                   NaN             840
# 493333         NaN       NaN                   NaN             840
# 493334         NaN       NaN                   NaN            \"\"
# 493335         NaN       NaN                   NaN             840
#
#        frgn_tran_amt  us_equiv_amt  posting_date
# 0              15.78           0.0    2024-06-06
# 1              14.85           0.0    2024-06-20
# 2             136.16           0.0    2024-06-27
# 3               8.74           0.0    2024-08-16
# 4              26.65           0.0    2024-08-18
# ...              ...           ...           ...
# 493331          3.99           0.0    2025-03-07
# 493332          6.13           0.0    2024-07-28
# 493333         15.62           0.0    2025-02-05
# 493334          0.00           0.0    2025-02-05
# 493335         44.14           0.0    2025-02-16
#
# [493336 rows x 21 columns]

# %%
df_rams = pd.read_csv("/Users/kaitlinbaggot/Desktop/datathon 2025/rams_batch_cur_20250325.csv")
df_rams
# Out:
#        cu_bhv_scr  ca_cash_bal_pct_crd_line  ca_cash_bal_pct_cash_line  \
# 0             779                         0                          0
# 1             735                         0                        999
# 2             745                         0                          0
# 3              13                         0                          0
# 4               6                         0                        999
# ...           ...                       ...                        ...
# 96794           6                         0                          0
# 96795         709                         0                          0
# 96796         755                         0                          0
# 96797         748                         0                          0
# 96798         752                         0                          0
#
#        cu_nbr_days_dlq  cu_nbr_of_plastics  ca_avg_utilz_lst_6_mnths  \
# 0                    0                   2                         2
# 1                    0                   1                         2
# 2                    0                   1                         2
# 3                    0                   1                         0
# 4                    0                   1                         7
# ...                ...                 ...                       ...
# 96794               30                   1                        15
# 96795                0                   1                         8
# 96796                0                   1                         5
# 96797                0                   1                         0
# 96798                0                   2                         0
#
#        cu_cash_line_am  cu_crd_bureau_scr  cu_crd_line  \
# 0                 5000                782        25000
# 1                    0                836         1500
# 2                 8000                832        40000
# 3                   60                684          300
# 4                    0                681         5200
# ...                ...                ...          ...
# 96794               90                711          900
# 96795  999999999999999                833         6700
# 96796             3320                759        16600
# 96797              800                788         4000
# 96798              510                826         2550
#
#        cu_next_crd_line_rev_date  ...  rb_new_bhv_scr  rb_crd_gr_new_crd_gr  \
# 0                              0  ...             776                     R
# 1                              0  ...             735                     R
# 2                              0  ...             748                     R
# 3                              0  ...              13                     O
# 4                              0  ...               6                     P
# ...                          ...  ...             ...                   ...
# 96794                          0  ...             628                     K
# 96795                          0  ...             703                     R
# 96796                          0  ...             761                     R
# 96797                          0  ...             748                     R
# 96798                          0  ...              13                     R
#
#        cu_processing_date mo_tot_sales_array_1 mo_tot_sales_array_2  \
# 0              2024-12-17               997.56               521.07
# 1              2025-02-21                 0.00                37.65
# 2              2024-10-10              1024.55               578.80
# 3              2025-01-27                 0.00                 0.00
# 4              2025-03-19               895.33                 0.00
# ...                   ...                  ...                  ...
# 96794          2024-11-14                 0.00               185.10
# 96795          2025-02-27                 0.00                 0.00
# 96796          2025-01-24              1037.83               899.65
# 96797          2025-02-20                 0.00                 0.00
# 96798          2025-03-21                 0.00                 0.00
#
#        mo_tot_sales_array_3  mo_tot_sales_array_4  mo_tot_sales_array_5  \
# 0                    647.86               1045.03                858.49
# 1                     60.25                175.67                 54.08
# 2                    665.81                816.43               2526.27
# 3                      0.00                  0.00                  0.00
# 4                      0.00                  0.00                  0.00
# ...                     ...                   ...                   ...
# 96794                  0.00                  0.00                  0.00
# 96795                  0.00                  0.00                  0.00
# 96796               1111.87                954.31                865.07
# 96797                  0.00                  0.00                 43.52
# 96798                  0.00                  0.00                  0.00
#
#        mo_tot_sales_array_6  ca_avg_utilz_lst_3_mnths
# 0                    334.54                         2
# 1                      0.00                         0
# 2                   3129.23                         1
# 3                      0.00                         0
# 4                      0.00                         7
# ...                     ...                       ...
# 96794                  0.00                        15
# 96795                  0.00                         7
# 96796                912.63                         5
# 96797                  0.00                         0
# 96798                  0.00                         0
#
# [96799 rows x 32 columns]

# %%
df_rams["current_account_nbr"] = df_rams["cu_account_nbr"]
df_rams.drop(['cu_account_nbr'], axis=1)
# Out:
#        cu_bhv_scr  ca_cash_bal_pct_crd_line  ca_cash_bal_pct_cash_line  \
# 0             779                         0                          0
# 1             735                         0                        999
# 2             745                         0                          0
# 3              13                         0                          0
# 4               6                         0                        999
# ...           ...                       ...                        ...
# 96794           6                         0                          0
# 96795         709                         0                          0
# 96796         755                         0                          0
# 96797         748                         0                          0
# 96798         752                         0                          0
#
#        cu_nbr_days_dlq  cu_nbr_of_plastics  ca_avg_utilz_lst_6_mnths  \
# 0                    0                   2                         2
# 1                    0                   1                         2
# 2                    0                   1                         2
# 3                    0                   1                         0
# 4                    0                   1                         7
# ...                ...                 ...                       ...
# 96794               30                   1                        15
# 96795                0                   1                         8
# 96796                0                   1                         5
# 96797                0                   1                         0
# 96798                0                   2                         0
#
#        cu_cash_line_am  cu_crd_bureau_scr  cu_crd_line  \
# 0                 5000                782        25000
# 1                    0                836         1500
# 2                 8000                832        40000
# 3                   60                684          300
# 4                    0                681         5200
# ...                ...                ...          ...
# 96794               90                711          900
# 96795  999999999999999                833         6700
# 96796             3320                759        16600
# 96797              800                788         4000
# 96798              510                826         2550
#
#        cu_next_crd_line_rev_date  ...  rb_crd_gr_new_crd_gr  \
# 0                              0  ...                     R
# 1                              0  ...                     R
# 2                              0  ...                     R
# 3                              0  ...                     O
# 4                              0  ...                     P
# ...                          ...  ...                   ...
# 96794                          0  ...                     K
# 96795                          0  ...                     R
# 96796                          0  ...                     R
# 96797                          0  ...                     R
# 96798                          0  ...                     R
#
#        cu_processing_date  mo_tot_sales_array_1 mo_tot_sales_array_2  \
# 0              2024-12-17                997.56               521.07
# 1              2025-02-21                  0.00                37.65
# 2              2024-10-10               1024.55               578.80
# 3              2025-01-27                  0.00                 0.00
# 4              2025-03-19                895.33                 0.00
# ...                   ...                   ...                  ...
# 96794          2024-11-14                  0.00               185.10
# 96795          2025-02-27                  0.00                 0.00
# 96796          2025-01-24               1037.83               899.65
# 96797          2025-02-20                  0.00                 0.00
# 96798          2025-03-21                  0.00                 0.00
#
#        mo_tot_sales_array_3  mo_tot_sales_array_4  mo_tot_sales_array_5  \
# 0                    647.86               1045.03                858.49
# 1                     60.25                175.67                 54.08
# 2                    665.81                816.43               2526.27
# 3                      0.00                  0.00                  0.00
# 4                      0.00                  0.00                  0.00
# ...                     ...                   ...                   ...
# 96794                  0.00                  0.00                  0.00
# 96795                  0.00                  0.00                  0.00
# 96796               1111.87                954.31                865.07
# 96797                  0.00                  0.00                 43.52
# 96798                  0.00                  0.00                  0.00
#
#        mo_tot_sales_array_6  ca_avg_utilz_lst_3_mnths  current_account_nbr
# 0                    334.54                         2     37eHiwRArQ0A7jhs
# 1                      0.00                         0     UV2Z1ODsmodPM2eO
# 2                   3129.23                         1     VqweW0TxF93M2EF5
# 3                      0.00                         0     pfKs8HDpmFV3b1zL
# 4                      0.00                         7     35VRb2UTGapQk6wE
# ...                     ...                       ...                  ...
# 96794                  0.00                        15     Qc7bVxgbL7yLnwHk
# 96795                  0.00                         7     HaSj4cm2eeV1ddau
# 96796                912.63                         5     TUgAUpJzGvRCZPhr
# 96797                  0.00                         0     dCC3ETrdP8KNK5dM
# 96798                  0.00                         0     hQXaPLagczxxH5Ea
#
# [96799 rows x 32 columns]

# %%
df_fraud = pd.read_csv("/Users/kaitlinbaggot/Desktop/datathon 2025/fraud_claim_case_20250325.csv")
df_fraud
# Out:
#    current_account_nbr        case_id reported_date   open_date  close_date  \
# 0     ZB0SJEUntc0XyQuU  3202508301370    2025-03-23  2025-03-24         NaN
# 1     7zdxYCqGYTCFEKUb  4202235600151    2022-11-30  2022-12-22  2023-01-19
# 2     VT29T3VPWCZ8KEkI  3202306200632    2023-03-02  2023-03-03  2023-04-14
# 3     FqHTEAbjd4z65FWv  3202305801521    2023-02-26  2023-02-27  2023-04-09
# 4     BG4qfLXo8chh5tIY  1202507200260    2025-03-11  2025-03-13         NaN
# ..                 ...            ...           ...         ...         ...
# 72    3Hj6EuxP2uay1tZR  3202315301546    2023-06-01  2023-06-02  2023-06-13
# 73    P586ALgLRL6ldsIW  1202208000284    2022-03-18  2022-03-21  2022-06-27
# 74    apaOOlllTbXSAlVZ  1202507800267    2025-03-17  2025-03-19  2025-03-20
# 75    te0g3zNNAJ1cas4X  4202300200579    2023-01-01  2023-01-02  2023-01-19
# 76    pk8zhE2r1i7zjsNA  4202508401061    2025-03-24  2025-03-25         NaN
#
#    reopen_date  gross_fraud_amt  net_fraud_amt
# 0          NaN          1789.82        1789.82
# 1   2023-01-10            71.87           0.00
# 2   2023-04-13           184.21           0.00
# 3   2023-04-07           672.60           0.00
# 4          NaN            79.48          79.48
# ..         ...              ...            ...
# 72         NaN           239.88           0.00
# 73  2022-06-24           142.36           0.00
# 74         NaN            70.43           0.00
# 75         NaN            25.00           0.00
# 76         NaN             0.00           0.00
#
# [77 rows x 8 columns]

# %%
df_world_trans = pd.read_csv("/Users/kaitlinbaggot/Desktop/datathon 2025/wrld_stor_tran_fact_20250325.csv")
df_world_trans
# Out:
#         current_account_nbr transaction_type  transaction_code  \
# 0          8DPC9336FwGf8TPz             SALE               253
# 1          DRTiAtZURdSfMAB0             SALE               253
# 2          4y1CqjRDtP3w8Nb5             SALE               253
# 3          3dPDITyRPlzdq3wf             SALE               253
# 4          q1mnsZTeAaQH71AF             SALE               253
# ...                     ...              ...               ...
# 1053849    uqlll7MEoZkj3vur             SALE               253
# 1053850    ZGjYc8aETjtytUYR             SALE               253
# 1053851    4JpGONAzyfmoxi7A             SALE               253
# 1053852    tUUUlJJZ2ETedT7g             SALE               253
# 1053853    u7AfBCIabLPkr5y7             SALE               253
#
#         transaction_date  transaction_amt  payment_type  \
# 0             2024-04-29            47.40           NaN
# 1             2024-06-25            87.13           NaN
# 2             2024-08-06            30.00           NaN
# 3             2024-09-05            32.30           NaN
# 4             2024-12-30             4.40           NaN
# ...                  ...              ...           ...
# 1053849       2024-11-12             9.57           NaN
# 1053850       2025-03-10            16.11           NaN
# 1053851       2025-03-20            20.37           NaN
# 1053852       2024-11-21           180.00           NaN
# 1053853       2024-12-08             2.50           NaN
#
#          transaction_return_cnt  transaction_sale_cnt  product_amt  \
# 0                             0                     1          NaN
# 1                             0                     1          NaN
# 2                             0                     1          NaN
# 3                             0                     1          NaN
# 4                             0                     1          NaN
# ...                         ...                   ...          ...
# 1053849                       0                     1          NaN
# 1053850                       0                     1          NaN
# 1053851                       0                     1          NaN
# 1053852                       0                     1          NaN
# 1053853                       0                     1          NaN
#
#          product_qty  ...  first_purchase_ind adj_orgn_tran_dt  \
# 0                NaN  ...                   N       2024-03-17
# 1                NaN  ...                   N              NaN
# 2                NaN  ...                   N              NaN
# 3                NaN  ...                   N              NaN
# 4                NaN  ...                   N              NaN
# ...              ...  ...                 ...              ...
# 1053849          NaN  ...                   N              NaN
# 1053850          NaN  ...                   N              NaN
# 1053851          NaN  ...                   N       2025-02-26
# 1053852          NaN  ...                   N       2024-11-12
# 1053853          NaN  ...                   N       2024-11-06
#
#         curr_markup_fee  fcr_amount  fcr_flag  fcr_rate_of_exchange  \
# 0                   0.0         NaN       NaN                   NaN
# 1                   0.0         NaN       NaN                   NaN
# 2                   0.0         NaN       NaN                   NaN
# 3                   0.0         NaN       NaN                   NaN
# 4                   0.0         NaN       NaN                   NaN
# ...                 ...         ...       ...                   ...
# 1053849             0.0         NaN       NaN                   NaN
# 1053850             0.0         NaN       NaN                   NaN
# 1053851             0.0         NaN       NaN                   NaN
# 1053852             0.0         NaN       NaN                   NaN
# 1053853             0.0         NaN       NaN                   NaN
#
#          frgn_curr_code frgn_tran_amt  us_equiv_amt  posting_date
# 0                   840         47.40           0.0    2024-04-30
# 1                   840         87.13           0.0    2024-06-27
# 2                   840         30.00           0.0    2024-08-07
# 3                   840         32.30           0.0    2024-09-05
# 4                   840          4.40           0.0    2024-12-31
# ...                 ...           ...           ...           ...
# 1053849             840          9.57           0.0    2024-11-13
# 1053850             840         16.11           0.0    2025-03-11
# 1053851             840         20.37           0.0    2025-03-21
# 1053852             840        180.00           0.0    2024-11-22
# 1053853             840          2.50           0.0    2024-12-09
#
# [1053854 rows x 21 columns]

# %% [markdown]
# ## Making Sense of Transactions Data

# %% [markdown]
# ### Transactions Cleaning

# %%
df_transactions_highest = df_transactions.groupby("current_account_nbr")["transaction_amt"].max()
df_transactions_highest
# Out:
# current_account_nbr
# 00gwujJkd597VxLd      25.90
# 00iP5U82D8XwVQ9G     681.86
# 00oyr3QppAzjLws4     145.20
# 02WRVV8yusgcZWLW    5788.49
# 033o9yHYen3xoz6k    3182.10
#                      ...
# zyikbceuTT3GcAH6       0.00
# zz3nbtZXS41NZk0h      84.91
# zzBy2qNM78aRV580     400.00
# zzEuUBBmvGiVnabb    3635.15
# zzR9PvG7dY9u5iHU     601.05
# Name: transaction_amt, Length: 14099, dtype: float64

# %%
df_transactions_clean = df_transactions.drop(['product_amt', 'product_qty', 'invoice_nbr',
 'first_purchase_ind',
 'adj_orgn_tran_dt',
 'curr_markup_fee',
 'fcr_amount',
 'fcr_flag',
 'fcr_rate_of_exchange',
 'frgn_curr_code',
 'frgn_tran_amt',
 'us_equiv_amt',
 'posting_date'], axis=1)
df_transactions_clean
# Out:
#        current_account_nbr transaction_type  transaction_code  \
# 0         X7jfKh6xrPAB8Tx6             SALE               253
# 1         yntD77AZDylS48Q4             SALE               253
# 2         LIJPI0sK28Pa7fX2             SALE               253
# 3         CMAr5Apxwdzpvoze             SALE               253
# 4         eJSfTCGPvJulGzd3             SALE               253
# ...                    ...              ...               ...
# 493331    ktpdvlbVRuywp2Po             SALE               253
# 493332    xwgOt4lvAHr517sa             SALE               253
# 493333    zp60CmOQNComnHDT             SALE               253
# 493334    8M5fnshTsgW9mW8Y          PAYMENT               271
# 493335    qT645tAyt7uDVJtL           RETURN               255
#
#        transaction_date  transaction_amt  payment_type  \
# 0            2024-06-05            15.78           NaN
# 1            2024-06-19            14.85           NaN
# 2            2024-06-26           136.16           NaN
# 3            2024-08-15             8.74           NaN
# 4            2024-08-17            26.65           NaN
# ...                 ...              ...           ...
# 493331       2025-03-07             3.99           NaN
# 493332       2024-07-27             6.13           NaN
# 493333       2025-02-04            15.62           NaN
# 493334       2025-02-05           100.00           NaN
# 493335       2025-02-14            44.14           NaN
#
#         transaction_return_cnt  transaction_sale_cnt
# 0                            0                     1
# 1                            0                     1
# 2                            0                     1
# 3                            0                     1
# 4                            0                     1
# ...                        ...                   ...
# 493331                       0                     1
# 493332                       0                     1
# 493333                       0                     1
# 493334                       0                     0
# 493335                       1                     0
#
# [493336 rows x 8 columns]

# %%
df_transactions_clean = df_transactions_clean[df_transactions_clean["transaction_type"] != "ADJUSTMENT"]
df_transactions_clean
# Out:
#        current_account_nbr transaction_type  transaction_code  \
# 0         X7jfKh6xrPAB8Tx6             SALE               253
# 1         yntD77AZDylS48Q4             SALE               253
# 2         LIJPI0sK28Pa7fX2             SALE               253
# 3         CMAr5Apxwdzpvoze             SALE               253
# 4         eJSfTCGPvJulGzd3             SALE               253
# ...                    ...              ...               ...
# 493331    ktpdvlbVRuywp2Po             SALE               253
# 493332    xwgOt4lvAHr517sa             SALE               253
# 493333    zp60CmOQNComnHDT             SALE               253
# 493334    8M5fnshTsgW9mW8Y          PAYMENT               271
# 493335    qT645tAyt7uDVJtL           RETURN               255
#
#        transaction_date  transaction_amt  payment_type  \
# 0            2024-06-05            15.78           NaN
# 1            2024-06-19            14.85           NaN
# 2            2024-06-26           136.16           NaN
# 3            2024-08-15             8.74           NaN
# 4            2024-08-17            26.65           NaN
# ...                 ...              ...           ...
# 493331       2025-03-07             3.99           NaN
# 493332       2024-07-27             6.13           NaN
# 493333       2025-02-04            15.62           NaN
# 493334       2025-02-05           100.00           NaN
# 493335       2025-02-14            44.14           NaN
#
#         transaction_return_cnt  transaction_sale_cnt
# 0                            0                     1
# 1                            0                     1
# 2                            0                     1
# 3                            0                     1
# 4                            0                     1
# ...                        ...                   ...
# 493331                       0                     1
# 493332                       0                     1
# 493333                       0                     1
# 493334                       0                     0
# 493335                       1                     0
#
# [476217 rows x 8 columns]

# %%
df_transactions_clean = df_transactions_clean[df_transactions_clean["transaction_amt"] >= 0]
df_transactions_clean
# Out:
#        current_account_nbr transaction_type  transaction_code  \
# 0         X7jfKh6xrPAB8Tx6             SALE               253
# 1         yntD77AZDylS48Q4             SALE               253
# 2         LIJPI0sK28Pa7fX2             SALE               253
# 3         CMAr5Apxwdzpvoze             SALE               253
# 4         eJSfTCGPvJulGzd3             SALE               253
# ...                    ...              ...               ...
# 493331    ktpdvlbVRuywp2Po             SALE               253
# 493332    xwgOt4lvAHr517sa             SALE               253
# 493333    zp60CmOQNComnHDT             SALE               253
# 493334    8M5fnshTsgW9mW8Y          PAYMENT               271
# 493335    qT645tAyt7uDVJtL           RETURN               255
#
#        transaction_date  transaction_amt  payment_type  \
# 0            2024-06-05            15.78           NaN
# 1            2024-06-19            14.85           NaN
# 2            2024-06-26           136.16           NaN
# 3            2024-08-15             8.74           NaN
# 4            2024-08-17            26.65           NaN
# ...                 ...              ...           ...
# 493331       2025-03-07             3.99           NaN
# 493332       2024-07-27             6.13           NaN
# 493333       2025-02-04            15.62           NaN
# 493334       2025-02-05           100.00           NaN
# 493335       2025-02-14            44.14           NaN
#
#         transaction_return_cnt  transaction_sale_cnt
# 0                            0                     1
# 1                            0                     1
# 2                            0                     1
# 3                            0                     1
# 4                            0                     1
# ...                        ...                   ...
# 493331                       0                     1
# 493332                       0                     1
# 493333                       0                     1
# 493334                       0                     0
# 493335                       1                     0
#
# [476099 rows x 8 columns]

# %%
df_transactions_clean["transaction_date"].sort_values()
# Out:
# 437454    2023-05-15
# 447830    2023-05-17
# 437065    2023-06-15
# 439981    2023-07-15
# 235708    2023-08-10
#              ...
# 322039    2025-03-24
# 462791    2025-03-24
# 377848    2025-03-24
# 316403    2025-03-24
# 466053    2025-03-24
# Name: transaction_date, Length: 476099, dtype: object

# %%
df_transactions_Q1 = df_transactions_clean[df_transactions_clean["transaction_date"].astype(str).str.startswith(("2024-01", "2024-02", "2024-03"))]
df_transactions_Q1
# Out:
#        current_account_nbr transaction_type  transaction_code  \
# 11        ZSQKKuJzo3LNZetu             SALE               253
# 27        QhYFOuQGrdYrJ6UP             SALE               253
# 46        K1BMhCn54N0QzPWV             SALE               253
# 154       0h3bLL0KB6KQ9yLi          PAYMENT               271
# 176       JYcEYBYrKDNvSOCl             SALE               253
# ...                    ...              ...               ...
# 492947    T6nbuIZLuMwVCIxs             SALE               253
# 493024    KQg5vRR978TVG5RX             SALE               253
# 493082    jI8tKgN5OZkw36AX             SALE               253
# 493193    O3FJDKm7CuShNi1U             SALE               253
# 493302    tItOVyaQhmUEBaPd             SALE               253
#
#        transaction_date  transaction_amt  payment_type  \
# 11           2024-03-27            36.34           NaN
# 27           2024-03-25            18.26           NaN
# 46           2024-03-29           310.43           NaN
# 154          2024-03-29           125.00           NaN
# 176          2024-03-26            13.07           NaN
# ...                 ...              ...           ...
# 492947       2024-03-25            94.09           NaN
# 493024       2024-03-30            99.63           NaN
# 493082       2024-03-27            48.47           NaN
# 493193       2024-03-27            53.61           NaN
# 493302       2024-03-30           142.97           NaN
#
#         transaction_return_cnt  transaction_sale_cnt
# 11                           0                     1
# 27                           0                     1
# 46                           0                     1
# 154                          0                     0
# 176                          0                     1
# ...                        ...                   ...
# 492947                       0                     1
# 493024                       0                     1
# 493082                       0                     1
# 493193                       0                     1
# 493302                       0                     1
#
# [7047 rows x 8 columns]

# %%
df_transactions_Q2 = df_transactions_clean[df_transactions_clean["transaction_date"].astype(str).str.startswith(("2024-04", "2024-05", "2024-06"))]
df_transactions_Q2
# Out:
#        current_account_nbr transaction_type  transaction_code  \
# 0         X7jfKh6xrPAB8Tx6             SALE               253
# 1         yntD77AZDylS48Q4             SALE               253
# 2         LIJPI0sK28Pa7fX2             SALE               253
# 12        skrJCHycIiIu0EtI             SALE               253
# 17        GlGFcx3kCPAk9UfH             SALE               253
# ...                    ...              ...               ...
# 493289    VAPiHkL69htyF011             SALE               253
# 493292    ABoEIGMdfGiZwgf4             SALE               253
# 493293    Dqdyi9rqaiQZcWOZ             SALE               253
# 493306    8JVpw0YsqxQ1BsBK             SALE               253
# 493313    MU1KfUbiY6zvY7GH             SALE               253
#
#        transaction_date  transaction_amt  payment_type  \
# 0            2024-06-05            15.78           NaN
# 1            2024-06-19            14.85           NaN
# 2            2024-06-26           136.16           NaN
# 12           2024-06-17             5.00           NaN
# 17           2024-04-06            33.21           NaN
# ...                 ...              ...           ...
# 493289       2024-05-18            62.41           NaN
# 493292       2024-04-17           200.73           NaN
# 493293       2024-06-25             5.56           NaN
# 493306       2024-04-23            37.94           NaN
# 493313       2024-05-27             2.68           NaN
#
#         transaction_return_cnt  transaction_sale_cnt
# 0                            0                     1
# 1                            0                     1
# 2                            0                     1
# 12                           0                     1
# 17                           0                     1
# ...                        ...                   ...
# 493289                       0                     1
# 493292                       0                     1
# 493293                       0                     1
# 493306                       0                     1
# 493313                       0                     1
#
# [107367 rows x 8 columns]

# %%
df_transactions_Q3 = df_transactions_clean[df_transactions_clean["transaction_date"].astype(str).str.startswith(("2024-07", "2024-08", "2024-09"))]
df_transactions_Q3
# Out:
#        current_account_nbr transaction_type  transaction_code  \
# 3         CMAr5Apxwdzpvoze             SALE               253
# 4         eJSfTCGPvJulGzd3             SALE               253
# 13        edqKl2I8yKGHvNu8             SALE               253
# 29        adPZJ4iDtn41UyPp             SALE               253
# 32        ySq4LWV2tp1Hdyw9             SALE               253
# ...                    ...              ...               ...
# 493317    M1CjY8LQDAwCGFJn             SALE               253
# 493319    NQ5OKPRlkpEt0lg7          PAYMENT               271
# 493320    IKLMeHdyxDbz66CB           RETURN               255
# 493322    h9qq3XKELV9RiA44             SALE               253
# 493332    xwgOt4lvAHr517sa             SALE               253
#
#        transaction_date  transaction_amt  payment_type  \
# 3            2024-08-15             8.74           NaN
# 4            2024-08-17            26.65           NaN
# 13           2024-08-16           107.74           NaN
# 29           2024-07-08            34.80           NaN
# 32           2024-07-18            21.79           NaN
# ...                 ...              ...           ...
# 493317       2024-08-10             2.12           NaN
# 493319       2024-09-05            15.00           NaN
# 493320       2024-09-11           411.72           NaN
# 493322       2024-09-14            87.97           NaN
# 493332       2024-07-27             6.13           NaN
#
#         transaction_return_cnt  transaction_sale_cnt
# 3                            0                     1
# 4                            0                     1
# 13                           0                     1
# 29                           0                     1
# 32                           0                     1
# ...                        ...                   ...
# 493317                       0                     1
# 493319                       0                     0
# 493320                       1                     0
# 493322                       0                     1
# 493332                       0                     1
#
# [115548 rows x 8 columns]

# %%
df_transactions_Q4 = df_transactions_clean[df_transactions_clean["transaction_date"].astype(str).str.startswith(("2024-10", "2024-11", "2024-12"))]
df_transactions_Q4
# Out:
#        current_account_nbr transaction_type  transaction_code  \
# 5         AAGp1e2TujsQF0Tk             SALE               253
# 6         p0X0C6QU59pYocnI             SALE               253
# 14        Mb5wgeslW4eJ3Ctl             SALE               253
# 15        RMZQcREtbIsbzi5u             SALE               253
# 16        FePVFNPIklGA9tkE             SALE               253
# ...                    ...              ...               ...
# 493323    ZPQQCuk31GGkGOSa             SALE               253
# 493324    FPOLhsN1mFznZgBx             SALE               253
# 493325    0hYf7EviiXnkuQOo             SALE               253
# 493326    mKUxsiciAQAdUliE          PAYMENT               271
# 493328    2e9QxsB0GV6BKCG0          PAYMENT               271
#
#        transaction_date  transaction_amt  payment_type  \
# 5            2024-10-20            25.68           NaN
# 6            2024-12-14           358.62           NaN
# 14           2024-10-28           163.63           NaN
# 15           2024-12-29            97.70           NaN
# 16           2024-11-18            61.29           NaN
# ...                 ...              ...           ...
# 493323       2024-10-08             2.16           NaN
# 493324       2024-10-12            15.29           NaN
# 493325       2024-12-03             8.60           NaN
# 493326       2024-10-22         10880.72           NaN
# 493328       2024-11-02           100.00           NaN
#
#         transaction_return_cnt  transaction_sale_cnt
# 5                            0                     1
# 6                            0                     1
# 14                           0                     1
# 15                           0                     1
# 16                           0                     1
# ...                        ...                   ...
# 493323                       0                     1
# 493324                       0                     1
# 493325                       0                     1
# 493326                       0                     0
# 493328                       0                     0
#
# [131032 rows x 8 columns]

# %%
df_transactions_Q4["transaction_amt"].sort_values()
# Out:
# 241585        0.00
# 305873        0.00
# 27857         0.00
# 325144        0.00
# 55833         0.00
#             ...
# 307163    20338.41
# 192830    23907.22
# 74211     25039.51
# 347348    31183.00
# 279323    40200.00
# Name: transaction_amt, Length: 131032, dtype: float64

# %% [markdown]
# ### World Transactions Cleaning

# %%
df_world_trans_clean = df_world_trans.drop(['product_amt', 'product_qty', 'invoice_nbr',
 'first_purchase_ind',
 'adj_orgn_tran_dt',
 'curr_markup_fee',
 'fcr_amount',
 'fcr_flag',
 'fcr_rate_of_exchange',
 'frgn_curr_code',
 'frgn_tran_amt',
 'us_equiv_amt',
 'posting_date'], axis=1)
df_world_trans_clean
# Out:
#         current_account_nbr transaction_type  transaction_code  \
# 0          8DPC9336FwGf8TPz             SALE               253
# 1          DRTiAtZURdSfMAB0             SALE               253
# 2          4y1CqjRDtP3w8Nb5             SALE               253
# 3          3dPDITyRPlzdq3wf             SALE               253
# 4          q1mnsZTeAaQH71AF             SALE               253
# ...                     ...              ...               ...
# 1053849    uqlll7MEoZkj3vur             SALE               253
# 1053850    ZGjYc8aETjtytUYR             SALE               253
# 1053851    4JpGONAzyfmoxi7A             SALE               253
# 1053852    tUUUlJJZ2ETedT7g             SALE               253
# 1053853    u7AfBCIabLPkr5y7             SALE               253
#
#         transaction_date  transaction_amt  payment_type  \
# 0             2024-04-29            47.40           NaN
# 1             2024-06-25            87.13           NaN
# 2             2024-08-06            30.00           NaN
# 3             2024-09-05            32.30           NaN
# 4             2024-12-30             4.40           NaN
# ...                  ...              ...           ...
# 1053849       2024-11-12             9.57           NaN
# 1053850       2025-03-10            16.11           NaN
# 1053851       2025-03-20            20.37           NaN
# 1053852       2024-11-21           180.00           NaN
# 1053853       2024-12-08             2.50           NaN
#
#          transaction_return_cnt  transaction_sale_cnt
# 0                             0                     1
# 1                             0                     1
# 2                             0                     1
# 3                             0                     1
# 4                             0                     1
# ...                         ...                   ...
# 1053849                       0                     1
# 1053850                       0                     1
# 1053851                       0                     1
# 1053852                       0                     1
# 1053853                       0                     1
#
# [1053854 rows x 8 columns]

# %%
df_world_trans_clean = df_world_trans_clean[df_world_trans_clean["transaction_type"] != "ADJUSTMENT"]
df_world_trans_clean
# Out:
#         current_account_nbr transaction_type  transaction_code  \
# 0          8DPC9336FwGf8TPz             SALE               253
# 1          DRTiAtZURdSfMAB0             SALE               253
# 2          4y1CqjRDtP3w8Nb5             SALE               253
# 3          3dPDITyRPlzdq3wf             SALE               253
# 4          q1mnsZTeAaQH71AF             SALE               253
# ...                     ...              ...               ...
# 1053849    uqlll7MEoZkj3vur             SALE               253
# 1053850    ZGjYc8aETjtytUYR             SALE               253
# 1053851    4JpGONAzyfmoxi7A             SALE               253
# 1053852    tUUUlJJZ2ETedT7g             SALE               253
# 1053853    u7AfBCIabLPkr5y7             SALE               253
#
#         transaction_date  transaction_amt  payment_type  \
# 0             2024-04-29            47.40           NaN
# 1             2024-06-25            87.13           NaN
# 2             2024-08-06            30.00           NaN
# 3             2024-09-05            32.30           NaN
# 4             2024-12-30             4.40           NaN
# ...                  ...              ...           ...
# 1053849       2024-11-12             9.57           NaN
# 1053850       2025-03-10            16.11           NaN
# 1053851       2025-03-20            20.37           NaN
# 1053852       2024-11-21           180.00           NaN
# 1053853       2024-12-08             2.50           NaN
#
#          transaction_return_cnt  transaction_sale_cnt
# 0                             0                     1
# 1                             0                     1
# 2                             0                     1
# 3                             0                     1
# 4                             0                     1
# ...                         ...                   ...
# 1053849                       0                     1
# 1053850                       0                     1
# 1053851                       0                     1
# 1053852                       0                     1
# 1053853                       0                     1
#
# [1044549 rows x 8 columns]

# %%
df_world_trans_clean = df_world_trans_clean[df_world_trans_clean["transaction_amt"] >= 0]
df_world_trans_clean
# Out:
#         current_account_nbr transaction_type  transaction_code  \
# 0          8DPC9336FwGf8TPz             SALE               253
# 1          DRTiAtZURdSfMAB0             SALE               253
# 2          4y1CqjRDtP3w8Nb5             SALE               253
# 3          3dPDITyRPlzdq3wf             SALE               253
# 4          q1mnsZTeAaQH71AF             SALE               253
# ...                     ...              ...               ...
# 1053849    uqlll7MEoZkj3vur             SALE               253
# 1053850    ZGjYc8aETjtytUYR             SALE               253
# 1053851    4JpGONAzyfmoxi7A             SALE               253
# 1053852    tUUUlJJZ2ETedT7g             SALE               253
# 1053853    u7AfBCIabLPkr5y7             SALE               253
#
#         transaction_date  transaction_amt  payment_type  \
# 0             2024-04-29            47.40           NaN
# 1             2024-06-25            87.13           NaN
# 2             2024-08-06            30.00           NaN
# 3             2024-09-05            32.30           NaN
# 4             2024-12-30             4.40           NaN
# ...                  ...              ...           ...
# 1053849       2024-11-12             9.57           NaN
# 1053850       2025-03-10            16.11           NaN
# 1053851       2025-03-20            20.37           NaN
# 1053852       2024-11-21           180.00           NaN
# 1053853       2024-12-08             2.50           NaN
#
#          transaction_return_cnt  transaction_sale_cnt
# 0                             0                     1
# 1                             0                     1
# 2                             0                     1
# 3                             0                     1
# 4                             0                     1
# ...                         ...                   ...
# 1053849                       0                     1
# 1053850                       0                     1
# 1053851                       0                     1
# 1053852                       0                     1
# 1053853                       0                     1
#
# [1044138 rows x 8 columns]

# %%
df_world_trans_Q1 = df_world_trans_clean[df_world_trans_clean["transaction_date"].astype(str).str.startswith(("2024-01", "2024-02", "2024-03"))]
df_world_trans_Q1
# Out:
#         current_account_nbr transaction_type  transaction_code  \
# 68         QaNKjwqCx045rzLr             SALE               253
# 117        NJ5mp4zsRzpEShey             SALE               253
# 118        XZIpMKbx7PZIOeOy             SALE               253
# 167        csRVJNQ9lek65m2z             SALE               253
# 168        wiYwqGm4ht2naNYH             SALE               253
# ...                     ...              ...               ...
# 1053651    3RiM5svLt5UoMaTT           RETURN               255
# 1053710    7PfwMQJdajj1tlpn             SALE               253
# 1053769    9RUzMCcLCMAUvx6n             SALE               253
# 1053785    7Dzj9nR8CI2a2DtC             SALE               253
# 1053815    i3tKQTzKsrCo1UKf             SALE               253
#
#         transaction_date  transaction_amt  payment_type  \
# 68            2024-03-29            18.66           NaN
# 117           2024-03-30            44.92           NaN
# 118           2024-03-28            99.70           NaN
# 167           2024-03-26            25.28           NaN
# 168           2024-03-30             5.74           NaN
# ...                  ...              ...           ...
# 1053651       2024-03-29            10.60           NaN
# 1053710       2024-03-28           243.88           NaN
# 1053769       2024-03-29             8.40           NaN
# 1053785       2024-03-31             5.00           NaN
# 1053815       2024-03-30            30.77           NaN
#
#          transaction_return_cnt  transaction_sale_cnt
# 68                            0                     1
# 117                           0                     1
# 118                           0                     1
# 167                           0                     1
# 168                           0                     1
# ...                         ...                   ...
# 1053651                       1                     0
# 1053710                       0                     1
# 1053769                       0                     1
# 1053785                       0                     1
# 1053815                       0                     1
#
# [17508 rows x 8 columns]

# %%
df_world_trans_Q2 = df_world_trans_clean[df_world_trans_clean["transaction_date"].astype(str).str.startswith(("2024-04", "2024-05", "2024-06"))]
df_world_trans_Q2
# Out:
#         current_account_nbr transaction_type  transaction_code  \
# 0          8DPC9336FwGf8TPz             SALE               253
# 1          DRTiAtZURdSfMAB0             SALE               253
# 10         gIoHHQ3laMHoedVO             SALE               253
# 11         0LfFC0f2GAC0aS1f             SALE               253
# 12         QmvwvXtqHJm8Hx7b             SALE               253
# ...                     ...              ...               ...
# 1053811    Tbeo412vddxmO7FZ             SALE               253
# 1053816    LjB2nrI82RbjXXrt             SALE               253
# 1053818    Xm3AmRGUAg62BMpb             SALE               253
# 1053819    4ILzV5Ka6nh4lWsB             SALE               253
# 1053829    SGnUCK5L7DMXvydb             SALE               253
#
#         transaction_date  transaction_amt  payment_type  \
# 0             2024-04-29            47.40           NaN
# 1             2024-06-25            87.13           NaN
# 10            2024-04-03             9.06           NaN
# 11            2024-04-22           278.00           NaN
# 12            2024-05-03             3.00           NaN
# ...                  ...              ...           ...
# 1053811       2024-04-22           281.33           NaN
# 1053816       2024-05-05             4.99           NaN
# 1053818       2024-05-30            24.01           NaN
# 1053819       2024-05-05            13.66           NaN
# 1053829       2024-06-21           223.00           NaN
#
#          transaction_return_cnt  transaction_sale_cnt
# 0                             0                     1
# 1                             0                     1
# 10                            0                     1
# 11                            0                     1
# 12                            0                     1
# ...                         ...                   ...
# 1053811                       0                     1
# 1053816                       0                     1
# 1053818                       0                     1
# 1053819                       0                     1
# 1053829                       0                     1
#
# [239307 rows x 8 columns]

# %%
df_world_trans_Q3 = df_world_trans_clean[df_world_trans_clean["transaction_date"].astype(str).str.startswith(("2024-07", "2024-08", "2024-09"))]
df_world_trans_Q3
# Out:
#         current_account_nbr transaction_type  transaction_code  \
# 2          4y1CqjRDtP3w8Nb5             SALE               253
# 3          3dPDITyRPlzdq3wf             SALE               253
# 13         lP4GKw5e42TtVjyi             SALE               253
# 26         6CdqBsCaDEsevnsp             SALE               253
# 31         qVsKGsk8ahYae4kX             SALE               253
# ...                     ...              ...               ...
# 1053817    OXSY4vvAXSrrmV1V             SALE               253
# 1053820    lP4GKw5e42TtVjyi             SALE               253
# 1053823    pOKwgCrIXtjUkdZr             SALE               253
# 1053824    J5KM6VrXlpeiISLM             SALE               253
# 1053838    U5ENDnVUG2Hw2dYh             SALE               253
#
#         transaction_date  transaction_amt  payment_type  \
# 2             2024-08-06            30.00           NaN
# 3             2024-09-05            32.30           NaN
# 13            2024-07-23           328.10           NaN
# 26            2024-07-15            28.03           NaN
# 31            2024-07-01             4.19           NaN
# ...                  ...              ...           ...
# 1053817       2024-09-03            76.10           NaN
# 1053820       2024-07-23           328.10           NaN
# 1053823       2024-08-15            16.66           NaN
# 1053824       2024-09-21            30.66           NaN
# 1053838       2024-07-11           300.00           NaN
#
#          transaction_return_cnt  transaction_sale_cnt
# 2                             0                     1
# 3                             0                     1
# 13                            0                     1
# 26                            0                     1
# 31                            0                     1
# ...                         ...                   ...
# 1053817                       0                     1
# 1053820                       0                     1
# 1053823                       0                     1
# 1053824                       0                     1
# 1053838                       0                     1
#
# [257113 rows x 8 columns]

# %%
df_world_trans_Q4 = df_world_trans_clean[df_world_trans_clean["transaction_date"].astype(str).str.startswith(("2024-10", "2024-11", "2024-12"))]
df_world_trans_Q4
# Out:
#         current_account_nbr transaction_type  transaction_code  \
# 4          q1mnsZTeAaQH71AF             SALE               253
# 5          m7ca9TUV8qbWJkcb             SALE               253
# 9          cmzM4aYbijSJMEG2             SALE               253
# 14         pOKwgCrIXtjUkdZr             SALE               253
# 15         S9R9Edu0bMIyfUnE             SALE               253
# ...                     ...              ...               ...
# 1053844    9gJsz8tSaVOwokPd             SALE               253
# 1053847    WBBqIOirecnTtAoI             SALE               253
# 1053849    uqlll7MEoZkj3vur             SALE               253
# 1053852    tUUUlJJZ2ETedT7g             SALE               253
# 1053853    u7AfBCIabLPkr5y7             SALE               253
#
#         transaction_date  transaction_amt  payment_type  \
# 4             2024-12-30             4.40           NaN
# 5             2024-12-29            22.72           NaN
# 9             2024-10-08            12.00           NaN
# 14            2024-12-04            27.66           NaN
# 15            2024-12-19            59.37           NaN
# ...                  ...              ...           ...
# 1053844       2024-10-12            25.67           NaN
# 1053847       2024-10-18            17.48           NaN
# 1053849       2024-11-12             9.57           NaN
# 1053852       2024-11-21           180.00           NaN
# 1053853       2024-12-08             2.50           NaN
#
#          transaction_return_cnt  transaction_sale_cnt
# 4                             0                     1
# 5                             0                     1
# 9                             0                     1
# 14                            0                     1
# 15                            0                     1
# ...                         ...                   ...
# 1053844                       0                     1
# 1053847                       0                     1
# 1053849                       0                     1
# 1053852                       0                     1
# 1053853                       0                     1
#
# [285136 rows x 8 columns]

# %% [markdown]
# ## Getting Q1-Q3 Trends

# %% [markdown]
# ### Transactions Q1 - Q3

# %%
df_transactions_Q3_sum = df_transactions_Q3.groupby("current_account_nbr").agg(
    total_spent = ("transaction_amt", "sum"),
    avg_transaction_amt = ("transaction_amt", "mean")
)
df_transactions_Q3_sum
# Out:
#                      total_spent  avg_transaction_amt
# current_account_nbr
# 00iP5U82D8XwVQ9G         2262.72            14.692987
# 00oyr3QppAzjLws4          390.04            78.008000
# 033o9yHYen3xoz6k         5386.87           414.374615
# 034bM166vNmgLiIA         1107.85           369.283333
# 03n28YA8ljfM9tor          622.16           311.080000
# ...                          ...                  ...
# zxn3AYXktnnqqYRJ         1628.11           116.293571
# zxwuHFEBf4ERmY9F         1022.80            73.057143
# zyZhjzJwhpOgSvmc         1909.55           146.888462
# zzBy2qNM78aRV580         1930.00           214.444444
# zzEuUBBmvGiVnabb         3143.44           285.767273
#
# [9889 rows x 2 columns]

# %%
df_transactions_Q2_sum = df_transactions_Q2.groupby("current_account_nbr").agg(
    total_spent = ("transaction_amt", "sum"),
    avg_transaction_amt = ("transaction_amt", "mean")
)
df_transactions_Q2_sum
# Out:
#                      total_spent  avg_transaction_amt
# current_account_nbr
# 00iP5U82D8XwVQ9G         1301.59            14.303187
# 00oyr3QppAzjLws4          625.52            78.190000
# 033o9yHYen3xoz6k         4911.03           306.939375
# 034bM166vNmgLiIA           19.98             9.990000
# 03n28YA8ljfM9tor          111.11           111.110000
# ...                          ...                  ...
# zxn3AYXktnnqqYRJ         5349.70           297.205556
# zxwuHFEBf4ERmY9F         8787.41           351.496400
# zyZhjzJwhpOgSvmc          495.26            99.052000
# zzBy2qNM78aRV580          207.00           103.500000
# zzEuUBBmvGiVnabb         4518.18           322.727143
#
# [9137 rows x 2 columns]

# %%
df_transactions_Q1_sum = df_transactions_Q1.groupby("current_account_nbr").agg(
    total_spent = ("transaction_amt", "sum"),
    avg_transaction_amt = ("transaction_amt", "mean")
)
df_transactions_Q1_sum
# Out:
#                      total_spent  avg_transaction_amt
# current_account_nbr
# 00iP5U82D8XwVQ9G           93.23             6.659286
# 033o9yHYen3xoz6k         1252.33          1252.330000
# 03tBhY3OXJglD820          150.00           150.000000
# 05AfSsd6epxXiK01          136.81            34.202500
# 05g3It0iVfAnv3ur            5.42             5.420000
# ...                          ...                  ...
# zsYIael1LtCzyZNe          151.08            21.582857
# zulSUhlkOQHtZWvu          126.99            63.495000
# zxn3AYXktnnqqYRJ            0.00             0.000000
# zxwuHFEBf4ERmY9F          179.47            59.823333
# zzEuUBBmvGiVnabb          542.26           271.130000
#
# [3249 rows x 2 columns]

# %%
df_transactions_Q1_to_Q3 = pd.merge(df_transactions_Q1_sum, df_transactions_Q2_sum, on="current_account_nbr")
df_transactions_Q1_to_Q3
# Out:
#                      total_spent_x  avg_transaction_amt_x  total_spent_y  \
# current_account_nbr
# 00iP5U82D8XwVQ9G             93.23               6.659286        1301.59
# 033o9yHYen3xoz6k           1252.33            1252.330000        4911.03
# 03tBhY3OXJglD820            150.00             150.000000        2150.00
# 05AfSsd6epxXiK01            136.81              34.202500       16891.64
# 05g3It0iVfAnv3ur              5.42               5.420000         258.09
# ...                            ...                    ...            ...
# zsYIael1LtCzyZNe            151.08              21.582857        5480.26
# zulSUhlkOQHtZWvu            126.99              63.495000        1706.10
# zxn3AYXktnnqqYRJ              0.00               0.000000        5349.70
# zxwuHFEBf4ERmY9F            179.47              59.823333        8787.41
# zzEuUBBmvGiVnabb            542.26             271.130000        4518.18
#
#                      avg_transaction_amt_y
# current_account_nbr
# 00iP5U82D8XwVQ9G                 14.303187
# 033o9yHYen3xoz6k                306.939375
# 03tBhY3OXJglD820                358.333333
# 05AfSsd6epxXiK01                383.900909
# 05g3It0iVfAnv3ur                 17.206000
# ...                                    ...
# zsYIael1LtCzyZNe                219.210400
# zulSUhlkOQHtZWvu                 60.932143
# zxn3AYXktnnqqYRJ                297.205556
# zxwuHFEBf4ERmY9F                351.496400
# zzEuUBBmvGiVnabb                322.727143
#
# [3194 rows x 4 columns]

# %%
df_transactions_Q1_to_Q3 = pd.merge(df_transactions_Q1_to_Q3, df_transactions_Q3_sum, on="current_account_nbr")
df_transactions_Q1_to_Q3
# Out:
#                      total_spent_x  avg_transaction_amt_x  total_spent_y  \
# current_account_nbr
# 00iP5U82D8XwVQ9G             93.23               6.659286        1301.59
# 033o9yHYen3xoz6k           1252.33            1252.330000        4911.03
# 03tBhY3OXJglD820            150.00             150.000000        2150.00
# 05AfSsd6epxXiK01            136.81              34.202500       16891.64
# 05g3It0iVfAnv3ur              5.42               5.420000         258.09
# ...                            ...                    ...            ...
# zsYIael1LtCzyZNe            151.08              21.582857        5480.26
# zulSUhlkOQHtZWvu            126.99              63.495000        1706.10
# zxn3AYXktnnqqYRJ              0.00               0.000000        5349.70
# zxwuHFEBf4ERmY9F            179.47              59.823333        8787.41
# zzEuUBBmvGiVnabb            542.26             271.130000        4518.18
#
#                      avg_transaction_amt_y  total_spent  avg_transaction_amt
# current_account_nbr
# 00iP5U82D8XwVQ9G                 14.303187      2262.72            14.692987
# 033o9yHYen3xoz6k                306.939375      5386.87           414.374615
# 03tBhY3OXJglD820                358.333333       471.00           117.750000
# 05AfSsd6epxXiK01                383.900909     18025.49           383.521064
# 05g3It0iVfAnv3ur                 17.206000      1391.01            51.518889
# ...                                    ...          ...                  ...
# zsYIael1LtCzyZNe                219.210400      3435.57           180.819474
# zulSUhlkOQHtZWvu                 60.932143      1529.97            72.855714
# zxn3AYXktnnqqYRJ                297.205556      1628.11           116.293571
# zxwuHFEBf4ERmY9F                351.496400      1022.80            73.057143
# zzEuUBBmvGiVnabb                322.727143      3143.44           285.767273
#
# [3060 rows x 6 columns]

# %%
df_transactions_Q1_to_Q3 = df_transactions_Q1_to_Q3.rename(columns={'total_spent_x': 'total_Q1', 
                                                                    'avg_transaction_amt_x': 'avg_trans_Q1', 
                                                                    'total_spent_y': 'total_Q2', 
                                                                    'avg_transaction_amt_y': 'avg_trans_Q2',
                                                                    'total_spent': 'total_Q3', 
                                                                    'avg_transaction_amt': 'avg_trans_Q3'})
df_transactions_Q1_to_Q3
# Out:
#                      total_Q1  avg_trans_Q1  total_Q2  avg_trans_Q2  total_Q3  \
# current_account_nbr
# 00iP5U82D8XwVQ9G        93.23      6.659286   1301.59     14.303187   2262.72
# 033o9yHYen3xoz6k      1252.33   1252.330000   4911.03    306.939375   5386.87
# 03tBhY3OXJglD820       150.00    150.000000   2150.00    358.333333    471.00
# 05AfSsd6epxXiK01       136.81     34.202500  16891.64    383.900909  18025.49
# 05g3It0iVfAnv3ur         5.42      5.420000    258.09     17.206000   1391.01
# ...                       ...           ...       ...           ...       ...
# zsYIael1LtCzyZNe       151.08     21.582857   5480.26    219.210400   3435.57
# zulSUhlkOQHtZWvu       126.99     63.495000   1706.10     60.932143   1529.97
# zxn3AYXktnnqqYRJ         0.00      0.000000   5349.70    297.205556   1628.11
# zxwuHFEBf4ERmY9F       179.47     59.823333   8787.41    351.496400   1022.80
# zzEuUBBmvGiVnabb       542.26    271.130000   4518.18    322.727143   3143.44
#
#                      avg_trans_Q3
# current_account_nbr
# 00iP5U82D8XwVQ9G        14.692987
# 033o9yHYen3xoz6k       414.374615
# 03tBhY3OXJglD820       117.750000
# 05AfSsd6epxXiK01       383.521064
# 05g3It0iVfAnv3ur        51.518889
# ...                           ...
# zsYIael1LtCzyZNe       180.819474
# zulSUhlkOQHtZWvu        72.855714
# zxn3AYXktnnqqYRJ       116.293571
# zxwuHFEBf4ERmY9F        73.057143
# zzEuUBBmvGiVnabb       285.767273
#
# [3060 rows x 6 columns]

# %% [markdown]
# ### World Transactions Q1 - Q3

# %%
df_world_trans_Q3_sum = df_world_trans_Q3.groupby("current_account_nbr").agg(
    total_spent = ("transaction_amt", "sum"),
    avg_transaction_amt = ("transaction_amt", "mean")
)
df_world_trans_Q3_sum
# Out:
#                      total_spent  avg_transaction_amt
# current_account_nbr
# 033o9yHYen3xoz6k         4811.56            48.115600
# 034bM166vNmgLiIA         1507.72            55.841481
# 049sX01uVFhaa0i2         7733.02            48.031180
# 05AfSsd6epxXiK01        20164.39           110.187923
# 05oLsFWaSLYzc5hv         1483.76            17.663810
# ...                          ...                  ...
# zuPY0iifqZT124F8          210.00            70.000000
# zwtnyO2BGLGWUf7r          728.03            60.669167
# zyZhjzJwhpOgSvmc         1405.01            36.025897
# zzBy2qNM78aRV580         2466.62          1233.310000
# zzEuUBBmvGiVnabb         2515.12            64.490256
#
# [4001 rows x 2 columns]

# %%
df_world_trans_Q2_sum = df_world_trans_Q2.groupby("current_account_nbr").agg(
    total_spent = ("transaction_amt", "sum"),
    avg_transaction_amt = ("transaction_amt", "mean")
)
df_world_trans_Q2_sum
# Out:
#                      total_spent  avg_transaction_amt
# current_account_nbr
# 033o9yHYen3xoz6k         3944.67            41.522842
# 049sX01uVFhaa0i2         5679.60            40.568571
# 05AfSsd6epxXiK01        12531.70            62.658500
# 05oLsFWaSLYzc5hv         2300.34            23.003400
# 062wBe4JtO4ij7Mp        11756.97            67.182686
# ...                          ...                  ...
# zuPY0iifqZT124F8          210.00            70.000000
# zwtnyO2BGLGWUf7r         1297.21            86.480667
# zyZhjzJwhpOgSvmc          615.72            36.218824
# zzBy2qNM78aRV580          339.99           113.330000
# zzEuUBBmvGiVnabb         3076.11            76.902750
#
# [3495 rows x 2 columns]

# %%
df_world_trans_Q1_sum = df_world_trans_Q1.groupby("current_account_nbr").agg(
    total_spent = ("transaction_amt", "sum"),
    avg_transaction_amt = ("transaction_amt", "mean")
)
df_world_trans_Q1_sum
# Out:
#                      total_spent  avg_transaction_amt
# current_account_nbr
# 033o9yHYen3xoz6k          128.54            32.135000
# 049sX01uVFhaa0i2          203.79            29.112857
# 05AfSsd6epxXiK01          716.21            29.842083
# 05oLsFWaSLYzc5hv           73.70            12.283333
# 062wBe4JtO4ij7Mp         1135.44            70.965000
# ...                          ...                  ...
# zp60CmOQNComnHDT           56.91            18.970000
# zqLSCw6bJGUB019O          281.80           281.800000
# zsYIael1LtCzyZNe          296.44            37.055000
# zzBy2qNM78aRV580           71.91            71.910000
# zzEuUBBmvGiVnabb          580.45           145.112500
#
# [2274 rows x 2 columns]

# %%
df_world_trans_Q1_to_Q3 = pd.merge(df_world_trans_Q1_sum, df_world_trans_Q2_sum, on="current_account_nbr")
df_world_trans_Q1_to_Q3
# Out:
#                      total_spent_x  avg_transaction_amt_x  total_spent_y  \
# current_account_nbr
# 033o9yHYen3xoz6k            128.54              32.135000        3944.67
# 049sX01uVFhaa0i2            203.79              29.112857        5679.60
# 05AfSsd6epxXiK01            716.21              29.842083       12531.70
# 05oLsFWaSLYzc5hv             73.70              12.283333        2300.34
# 062wBe4JtO4ij7Mp           1135.44              70.965000       11756.97
# ...                            ...                    ...            ...
# zoD9wnDwZFJyCtcj             66.59              13.318000        1866.99
# zp60CmOQNComnHDT             56.91              18.970000        7328.97
# zsYIael1LtCzyZNe            296.44              37.055000        3035.60
# zzBy2qNM78aRV580             71.91              71.910000         339.99
# zzEuUBBmvGiVnabb            580.45             145.112500        3076.11
#
#                      avg_transaction_amt_y
# current_account_nbr
# 033o9yHYen3xoz6k                 41.522842
# 049sX01uVFhaa0i2                 40.568571
# 05AfSsd6epxXiK01                 62.658500
# 05oLsFWaSLYzc5hv                 23.003400
# 062wBe4JtO4ij7Mp                 67.182686
# ...                                    ...
# zoD9wnDwZFJyCtcj                 20.744333
# zp60CmOQNComnHDT                 43.366686
# zsYIael1LtCzyZNe                151.780000
# zzBy2qNM78aRV580                113.330000
# zzEuUBBmvGiVnabb                 76.902750
#
# [2253 rows x 4 columns]

# %%
df_world_trans_Q1_to_Q3 = pd.merge(df_world_trans_Q1_to_Q3, df_world_trans_Q3_sum, on="current_account_nbr")
df_world_trans_Q1_to_Q3
# Out:
#                      total_spent_x  avg_transaction_amt_x  total_spent_y  \
# current_account_nbr
# 033o9yHYen3xoz6k            128.54              32.135000        3944.67
# 049sX01uVFhaa0i2            203.79              29.112857        5679.60
# 05AfSsd6epxXiK01            716.21              29.842083       12531.70
# 05oLsFWaSLYzc5hv             73.70              12.283333        2300.34
# 062wBe4JtO4ij7Mp           1135.44              70.965000       11756.97
# ...                            ...                    ...            ...
# zoD9wnDwZFJyCtcj             66.59              13.318000        1866.99
# zp60CmOQNComnHDT             56.91              18.970000        7328.97
# zsYIael1LtCzyZNe            296.44              37.055000        3035.60
# zzBy2qNM78aRV580             71.91              71.910000         339.99
# zzEuUBBmvGiVnabb            580.45             145.112500        3076.11
#
#                      avg_transaction_amt_y  total_spent  avg_transaction_amt
# current_account_nbr
# 033o9yHYen3xoz6k                 41.522842      4811.56            48.115600
# 049sX01uVFhaa0i2                 40.568571      7733.02            48.031180
# 05AfSsd6epxXiK01                 62.658500     20164.39           110.187923
# 05oLsFWaSLYzc5hv                 23.003400      1483.76            17.663810
# 062wBe4JtO4ij7Mp                 67.182686     12397.09            85.497172
# ...                                    ...          ...                  ...
# zoD9wnDwZFJyCtcj                 20.744333      1644.25            16.279703
# zp60CmOQNComnHDT                 43.366686     21241.50           136.163462
# zsYIael1LtCzyZNe                151.780000      1082.72            56.985263
# zzBy2qNM78aRV580                113.330000      2466.62          1233.310000
# zzEuUBBmvGiVnabb                 76.902750      2515.12            64.490256
#
# [2215 rows x 6 columns]

# %%
df_world_trans_Q1_to_Q3 = df_world_trans_Q1_to_Q3.rename(columns={'total_spent_x': 'total_Q1', 
                                                                    'avg_transaction_amt_x': 'avg_trans_Q1', 
                                                                    'total_spent_y': 'total_Q2', 
                                                                    'avg_transaction_amt_y': 'avg_trans_Q2',
                                                                    'total_spent': 'total_Q3', 
                                                                    'avg_transaction_amt': 'avg_trans_Q3'})
df_world_trans_Q1_to_Q3
# Out:
#                      total_Q1  avg_trans_Q1  total_Q2  avg_trans_Q2  total_Q3  \
# current_account_nbr
# 033o9yHYen3xoz6k       128.54     32.135000   3944.67     41.522842   4811.56
# 049sX01uVFhaa0i2       203.79     29.112857   5679.60     40.568571   7733.02
# 05AfSsd6epxXiK01       716.21     29.842083  12531.70     62.658500  20164.39
# 05oLsFWaSLYzc5hv        73.70     12.283333   2300.34     23.003400   1483.76
# 062wBe4JtO4ij7Mp      1135.44     70.965000  11756.97     67.182686  12397.09
# ...                       ...           ...       ...           ...       ...
# zoD9wnDwZFJyCtcj        66.59     13.318000   1866.99     20.744333   1644.25
# zp60CmOQNComnHDT        56.91     18.970000   7328.97     43.366686  21241.50
# zsYIael1LtCzyZNe       296.44     37.055000   3035.60    151.780000   1082.72
# zzBy2qNM78aRV580        71.91     71.910000    339.99    113.330000   2466.62
# zzEuUBBmvGiVnabb       580.45    145.112500   3076.11     76.902750   2515.12
#
#                      avg_trans_Q3
# current_account_nbr
# 033o9yHYen3xoz6k        48.115600
# 049sX01uVFhaa0i2        48.031180
# 05AfSsd6epxXiK01       110.187923
# 05oLsFWaSLYzc5hv        17.663810
# 062wBe4JtO4ij7Mp        85.497172
# ...                           ...
# zoD9wnDwZFJyCtcj        16.279703
# zp60CmOQNComnHDT       136.163462
# zsYIael1LtCzyZNe        56.985263
# zzBy2qNM78aRV580      1233.310000
# zzEuUBBmvGiVnabb        64.490256
#
# [2215 rows x 6 columns]

# %% [markdown]
# ### Combining Non-World & World Transactions Q1 - Q3

# %%
df_total_trans_Q1_to_Q3 = pd.merge(df_transactions_Q1_to_Q3, df_world_trans_Q1_to_Q3, on="current_account_nbr")
df_total_trans_Q1_to_Q3
# Out:
#                      total_Q1_x  avg_trans_Q1_x  total_Q2_x  avg_trans_Q2_x  \
# current_account_nbr
# 033o9yHYen3xoz6k        1252.33     1252.330000     4911.03      306.939375
# 05AfSsd6epxXiK01         136.81       34.202500    16891.64      383.900909
# 05oLsFWaSLYzc5hv         135.66       45.220000     3437.04      214.815000
# 062wBe4JtO4ij7Mp         182.49       60.830000    15277.06      412.893514
# 06SijOFpCXUvw9hs        4901.97     2450.985000    13331.87      555.494583
# ...                         ...             ...         ...             ...
# znzcg2AkVtchRVjt          70.71       35.355000     5536.92      190.928276
# zoBLVNjS9F2gDeYk         114.57       57.285000    21313.72      507.469524
# zoD9wnDwZFJyCtcj         651.92      651.920000     2525.99      132.946842
# zsYIael1LtCzyZNe         151.08       21.582857     5480.26      219.210400
# zzEuUBBmvGiVnabb         542.26      271.130000     4518.18      322.727143
#
#                      total_Q3_x  avg_trans_Q3_x  total_Q1_y  avg_trans_Q1_y  \
# current_account_nbr
# 033o9yHYen3xoz6k        5386.87      414.374615      128.54       32.135000
# 05AfSsd6epxXiK01       18025.49      383.521064      716.21       29.842083
# 05oLsFWaSLYzc5hv        2447.56      106.415652       73.70       12.283333
# 062wBe4JtO4ij7Mp       17183.96      536.998750     1135.44       70.965000
# 06SijOFpCXUvw9hs        5988.97      239.558800      637.47       49.036154
# ...                         ...             ...         ...             ...
# znzcg2AkVtchRVjt        5485.21      203.155926      274.79       91.596667
# zoBLVNjS9F2gDeYk       39898.41     1049.958158      698.49       29.103750
# zoD9wnDwZFJyCtcj        3514.28      167.346667       66.59       13.318000
# zsYIael1LtCzyZNe        3435.57      180.819474      296.44       37.055000
# zzEuUBBmvGiVnabb        3143.44      285.767273      580.45      145.112500
#
#                      total_Q2_y  avg_trans_Q2_y  total_Q3_y  avg_trans_Q3_y
# current_account_nbr
# 033o9yHYen3xoz6k        3944.67       41.522842     4811.56       48.115600
# 05AfSsd6epxXiK01       12531.70       62.658500    20164.39      110.187923
# 05oLsFWaSLYzc5hv        2300.34       23.003400     1483.76       17.663810
# 062wBe4JtO4ij7Mp       11756.97       67.182686    12397.09       85.497172
# 06SijOFpCXUvw9hs        7853.50      153.990196     3883.71       45.690706
# ...                         ...             ...         ...             ...
# znzcg2AkVtchRVjt        2459.49       57.197442     2546.90       70.747222
# zoBLVNjS9F2gDeYk       29980.20       97.974510    20571.44       56.514945
# zoD9wnDwZFJyCtcj        1866.99       20.744333     1644.25       16.279703
# zsYIael1LtCzyZNe        3035.60      151.780000     1082.72       56.985263
# zzEuUBBmvGiVnabb        3076.11       76.902750     2515.12       64.490256
#
# [1499 rows x 12 columns]

# %%
df_total_trans_Q1_to_Q3["total_Q1"] = df_total_trans_Q1_to_Q3["total_Q1_x"] + df_total_trans_Q1_to_Q3["total_Q1_y"]
df_total_trans_Q1_to_Q3["total_Q2"] = df_total_trans_Q1_to_Q3["total_Q2_x"] + df_total_trans_Q1_to_Q3["total_Q2_y"]
df_total_trans_Q1_to_Q3["total_Q3"] = df_total_trans_Q1_to_Q3["total_Q3_x"] + df_total_trans_Q1_to_Q3["total_Q3_y"]
df_total_trans_Q1_to_Q3
# Out:
#                      total_Q1_x  avg_trans_Q1_x  total_Q2_x  avg_trans_Q2_x  \
# current_account_nbr
# 033o9yHYen3xoz6k        1252.33     1252.330000     4911.03      306.939375
# 05AfSsd6epxXiK01         136.81       34.202500    16891.64      383.900909
# 05oLsFWaSLYzc5hv         135.66       45.220000     3437.04      214.815000
# 062wBe4JtO4ij7Mp         182.49       60.830000    15277.06      412.893514
# 06SijOFpCXUvw9hs        4901.97     2450.985000    13331.87      555.494583
# ...                         ...             ...         ...             ...
# znzcg2AkVtchRVjt          70.71       35.355000     5536.92      190.928276
# zoBLVNjS9F2gDeYk         114.57       57.285000    21313.72      507.469524
# zoD9wnDwZFJyCtcj         651.92      651.920000     2525.99      132.946842
# zsYIael1LtCzyZNe         151.08       21.582857     5480.26      219.210400
# zzEuUBBmvGiVnabb         542.26      271.130000     4518.18      322.727143
#
#                      total_Q3_x  avg_trans_Q3_x  total_Q1_y  avg_trans_Q1_y  \
# current_account_nbr
# 033o9yHYen3xoz6k        5386.87      414.374615      128.54       32.135000
# 05AfSsd6epxXiK01       18025.49      383.521064      716.21       29.842083
# 05oLsFWaSLYzc5hv        2447.56      106.415652       73.70       12.283333
# 062wBe4JtO4ij7Mp       17183.96      536.998750     1135.44       70.965000
# 06SijOFpCXUvw9hs        5988.97      239.558800      637.47       49.036154
# ...                         ...             ...         ...             ...
# znzcg2AkVtchRVjt        5485.21      203.155926      274.79       91.596667
# zoBLVNjS9F2gDeYk       39898.41     1049.958158      698.49       29.103750
# zoD9wnDwZFJyCtcj        3514.28      167.346667       66.59       13.318000
# zsYIael1LtCzyZNe        3435.57      180.819474      296.44       37.055000
# zzEuUBBmvGiVnabb        3143.44      285.767273      580.45      145.112500
#
#                      total_Q2_y  avg_trans_Q2_y  total_Q3_y  avg_trans_Q3_y  \
# current_account_nbr
# 033o9yHYen3xoz6k        3944.67       41.522842     4811.56       48.115600
# 05AfSsd6epxXiK01       12531.70       62.658500    20164.39      110.187923
# 05oLsFWaSLYzc5hv        2300.34       23.003400     1483.76       17.663810
# 062wBe4JtO4ij7Mp       11756.97       67.182686    12397.09       85.497172
# 06SijOFpCXUvw9hs        7853.50      153.990196     3883.71       45.690706
# ...                         ...             ...         ...             ...
# znzcg2AkVtchRVjt        2459.49       57.197442     2546.90       70.747222
# zoBLVNjS9F2gDeYk       29980.20       97.974510    20571.44       56.514945
# zoD9wnDwZFJyCtcj        1866.99       20.744333     1644.25       16.279703
# zsYIael1LtCzyZNe        3035.60      151.780000     1082.72       56.985263
# zzEuUBBmvGiVnabb        3076.11       76.902750     2515.12       64.490256
#
#                      total_Q1  total_Q2  total_Q3
# current_account_nbr
# 033o9yHYen3xoz6k      1380.87   8855.70  10198.43
# 05AfSsd6epxXiK01       853.02  29423.34  38189.88
# 05oLsFWaSLYzc5hv       209.36   5737.38   3931.32
# 062wBe4JtO4ij7Mp      1317.93  27034.03  29581.05
# 06SijOFpCXUvw9hs      5539.44  21185.37   9872.68
# ...                       ...       ...       ...
# znzcg2AkVtchRVjt       345.50   7996.41   8032.11
# zoBLVNjS9F2gDeYk       813.06  51293.92  60469.85
# zoD9wnDwZFJyCtcj       718.51   4392.98   5158.53
# zsYIael1LtCzyZNe       447.52   8515.86   4518.29
# zzEuUBBmvGiVnabb      1122.71   7594.29   5658.56
#
# [1499 rows x 15 columns]

# %%
df_total_trans_Q1_to_Q3 = df_total_trans_Q1_to_Q3.drop(['total_Q1_x', 'total_Q1_y', 'total_Q2_x', 'total_Q2_y', 'total_Q3_x', 'total_Q3_y'], axis=1)
df_total_trans_Q1_to_Q3
# Out:
#                      avg_trans_Q1_x  avg_trans_Q2_x  avg_trans_Q3_x  \
# current_account_nbr
# 033o9yHYen3xoz6k        1252.330000      306.939375      414.374615
# 05AfSsd6epxXiK01          34.202500      383.900909      383.521064
# 05oLsFWaSLYzc5hv          45.220000      214.815000      106.415652
# 062wBe4JtO4ij7Mp          60.830000      412.893514      536.998750
# 06SijOFpCXUvw9hs        2450.985000      555.494583      239.558800
# ...                             ...             ...             ...
# znzcg2AkVtchRVjt          35.355000      190.928276      203.155926
# zoBLVNjS9F2gDeYk          57.285000      507.469524     1049.958158
# zoD9wnDwZFJyCtcj         651.920000      132.946842      167.346667
# zsYIael1LtCzyZNe          21.582857      219.210400      180.819474
# zzEuUBBmvGiVnabb         271.130000      322.727143      285.767273
#
#                      avg_trans_Q1_y  avg_trans_Q2_y  avg_trans_Q3_y  total_Q1  \
# current_account_nbr
# 033o9yHYen3xoz6k          32.135000       41.522842       48.115600   1380.87
# 05AfSsd6epxXiK01          29.842083       62.658500      110.187923    853.02
# 05oLsFWaSLYzc5hv          12.283333       23.003400       17.663810    209.36
# 062wBe4JtO4ij7Mp          70.965000       67.182686       85.497172   1317.93
# 06SijOFpCXUvw9hs          49.036154      153.990196       45.690706   5539.44
# ...                             ...             ...             ...       ...
# znzcg2AkVtchRVjt          91.596667       57.197442       70.747222    345.50
# zoBLVNjS9F2gDeYk          29.103750       97.974510       56.514945    813.06
# zoD9wnDwZFJyCtcj          13.318000       20.744333       16.279703    718.51
# zsYIael1LtCzyZNe          37.055000      151.780000       56.985263    447.52
# zzEuUBBmvGiVnabb         145.112500       76.902750       64.490256   1122.71
#
#                      total_Q2  total_Q3
# current_account_nbr
# 033o9yHYen3xoz6k      8855.70  10198.43
# 05AfSsd6epxXiK01     29423.34  38189.88
# 05oLsFWaSLYzc5hv      5737.38   3931.32
# 062wBe4JtO4ij7Mp     27034.03  29581.05
# 06SijOFpCXUvw9hs     21185.37   9872.68
# ...                       ...       ...
# znzcg2AkVtchRVjt      7996.41   8032.11
# zoBLVNjS9F2gDeYk     51293.92  60469.85
# zoD9wnDwZFJyCtcj      4392.98   5158.53
# zsYIael1LtCzyZNe      8515.86   4518.29
# zzEuUBBmvGiVnabb      7594.29   5658.56
#
# [1499 rows x 9 columns]

# %% [markdown]
# ## Getting Q4 Total Spending

# %%
df_transactions_Q4_sum = df_transactions_Q4.groupby("current_account_nbr").agg(
    total_spent = ("transaction_amt", "sum"),
    avg_transaction_amt = ("transaction_amt", "mean")
)
df_transactions_Q4_sum
# Out:
#                      total_spent  avg_transaction_amt
# current_account_nbr
# 00iP5U82D8XwVQ9G         3449.74            13.217395
# 00oyr3QppAzjLws4          515.96            73.708571
# 033o9yHYen3xoz6k         8042.30           473.076471
# 034bM166vNmgLiIA          488.01           162.670000
# 03cqv0gFjEIiQG0x           40.00            40.000000
# ...                          ...                  ...
# zxwuHFEBf4ERmY9F         1899.68            61.280000
# zyZhjzJwhpOgSvmc         2304.89           192.074167
# zz3nbtZXS41NZk0h          239.82            47.964000
# zzBy2qNM78aRV580          520.00           173.333333
# zzEuUBBmvGiVnabb         6271.05           627.105000
#
# [10579 rows x 2 columns]

# %%
df_world_trans_Q4_sum = df_world_trans_Q4.groupby("current_account_nbr").agg(
    total_spent = ("transaction_amt", "sum"),
    avg_transaction_amt = ("transaction_amt", "mean")
)
df_world_trans_Q4_sum
# Out:
#                      total_spent  avg_transaction_amt
# current_account_nbr
# 033o9yHYen3xoz6k         6529.56            46.639714
# 034bM166vNmgLiIA          719.39            37.862632
# 049sX01uVFhaa0i2         5720.27            45.398968
# 05AfSsd6epxXiK01        16524.12            76.500556
# 05oLsFWaSLYzc5hv          873.37            58.224667
# ...                          ...                  ...
# zuPY0iifqZT124F8          210.00            70.000000
# zwtnyO2BGLGWUf7r         2533.08            70.363333
# zxOqFgWke0qPQZIO            0.00             0.000000
# zyZhjzJwhpOgSvmc         1890.00            30.983607
# zzEuUBBmvGiVnabb         5971.36            86.541449
#
# [4394 rows x 2 columns]

# %%
df_trans_Q4_merged = pd.merge(df_transactions_Q4_sum, df_world_trans_Q4_sum, on="current_account_nbr")
df_trans_Q4_merged
# Out:
#                      total_spent_x  avg_transaction_amt_x  total_spent_y  \
# current_account_nbr
# 033o9yHYen3xoz6k           8042.30             473.076471        6529.56
# 034bM166vNmgLiIA            488.01             162.670000         719.39
# 049sX01uVFhaa0i2           7983.33             798.333000        5720.27
# 05AfSsd6epxXiK01          22205.66             370.094333       16524.12
# 05oLsFWaSLYzc5hv           2240.80             112.040000         873.37
# ...                            ...                    ...            ...
# zsYIael1LtCzyZNe           4557.63             162.772500        1565.53
# zwtnyO2BGLGWUf7r            700.00             233.333333        2533.08
# zxOqFgWke0qPQZIO            259.88              64.970000           0.00
# zyZhjzJwhpOgSvmc           2304.89             192.074167        1890.00
# zzEuUBBmvGiVnabb           6271.05             627.105000        5971.36
#
#                      avg_transaction_amt_y
# current_account_nbr
# 033o9yHYen3xoz6k                 46.639714
# 034bM166vNmgLiIA                 37.862632
# 049sX01uVFhaa0i2                 45.398968
# 05AfSsd6epxXiK01                 76.500556
# 05oLsFWaSLYzc5hv                 58.224667
# ...                                    ...
# zsYIael1LtCzyZNe                 44.729429
# zwtnyO2BGLGWUf7r                 70.363333
# zxOqFgWke0qPQZIO                  0.000000
# zyZhjzJwhpOgSvmc                 30.983607
# zzEuUBBmvGiVnabb                 86.541449
#
# [4192 rows x 4 columns]

# %%
df_trans_Q4_merged["last_Q4_spending"] = df_trans_Q4_merged["total_spent_x"] + df_trans_Q4_merged["total_spent_y"]
df_trans_Q4_merged
# Out:
#                      total_spent_x  avg_transaction_amt_x  total_spent_y  \
# current_account_nbr
# 033o9yHYen3xoz6k           8042.30             473.076471        6529.56
# 034bM166vNmgLiIA            488.01             162.670000         719.39
# 049sX01uVFhaa0i2           7983.33             798.333000        5720.27
# 05AfSsd6epxXiK01          22205.66             370.094333       16524.12
# 05oLsFWaSLYzc5hv           2240.80             112.040000         873.37
# ...                            ...                    ...            ...
# zsYIael1LtCzyZNe           4557.63             162.772500        1565.53
# zwtnyO2BGLGWUf7r            700.00             233.333333        2533.08
# zxOqFgWke0qPQZIO            259.88              64.970000           0.00
# zyZhjzJwhpOgSvmc           2304.89             192.074167        1890.00
# zzEuUBBmvGiVnabb           6271.05             627.105000        5971.36
#
#                      avg_transaction_amt_y  last_Q4_spending
# current_account_nbr
# 033o9yHYen3xoz6k                 46.639714          14571.86
# 034bM166vNmgLiIA                 37.862632           1207.40
# 049sX01uVFhaa0i2                 45.398968          13703.60
# 05AfSsd6epxXiK01                 76.500556          38729.78
# 05oLsFWaSLYzc5hv                 58.224667           3114.17
# ...                                    ...               ...
# zsYIael1LtCzyZNe                 44.729429           6123.16
# zwtnyO2BGLGWUf7r                 70.363333           3233.08
# zxOqFgWke0qPQZIO                  0.000000            259.88
# zyZhjzJwhpOgSvmc                 30.983607           4194.89
# zzEuUBBmvGiVnabb                 86.541449          12242.41
#
# [4192 rows x 5 columns]

# %%
df_trans_Q4_merged["avg_transaction_amt"] = df_trans_Q4_merged["avg_transaction_amt_x"]
df_trans_Q4_merged["avg_world_transaction_amt"] = df_trans_Q4_merged["avg_transaction_amt_y"]
df_trans_Q4_merged
# Out:
#                      total_spent_x  avg_transaction_amt_x  total_spent_y  \
# current_account_nbr
# 033o9yHYen3xoz6k           8042.30             473.076471        6529.56
# 034bM166vNmgLiIA            488.01             162.670000         719.39
# 049sX01uVFhaa0i2           7983.33             798.333000        5720.27
# 05AfSsd6epxXiK01          22205.66             370.094333       16524.12
# 05oLsFWaSLYzc5hv           2240.80             112.040000         873.37
# ...                            ...                    ...            ...
# zsYIael1LtCzyZNe           4557.63             162.772500        1565.53
# zwtnyO2BGLGWUf7r            700.00             233.333333        2533.08
# zxOqFgWke0qPQZIO            259.88              64.970000           0.00
# zyZhjzJwhpOgSvmc           2304.89             192.074167        1890.00
# zzEuUBBmvGiVnabb           6271.05             627.105000        5971.36
#
#                      avg_transaction_amt_y  last_Q4_spending  \
# current_account_nbr
# 033o9yHYen3xoz6k                 46.639714          14571.86
# 034bM166vNmgLiIA                 37.862632           1207.40
# 049sX01uVFhaa0i2                 45.398968          13703.60
# 05AfSsd6epxXiK01                 76.500556          38729.78
# 05oLsFWaSLYzc5hv                 58.224667           3114.17
# ...                                    ...               ...
# zsYIael1LtCzyZNe                 44.729429           6123.16
# zwtnyO2BGLGWUf7r                 70.363333           3233.08
# zxOqFgWke0qPQZIO                  0.000000            259.88
# zyZhjzJwhpOgSvmc                 30.983607           4194.89
# zzEuUBBmvGiVnabb                 86.541449          12242.41
#
#                      avg_transaction_amt  avg_world_transaction_amt
# current_account_nbr
# 033o9yHYen3xoz6k              473.076471                  46.639714
# 034bM166vNmgLiIA              162.670000                  37.862632
# 049sX01uVFhaa0i2              798.333000                  45.398968
# 05AfSsd6epxXiK01              370.094333                  76.500556
# 05oLsFWaSLYzc5hv              112.040000                  58.224667
# ...                                  ...                        ...
# zsYIael1LtCzyZNe              162.772500                  44.729429
# zwtnyO2BGLGWUf7r              233.333333                  70.363333
# zxOqFgWke0qPQZIO               64.970000                   0.000000
# zyZhjzJwhpOgSvmc              192.074167                  30.983607
# zzEuUBBmvGiVnabb              627.105000                  86.541449
#
# [4192 rows x 7 columns]

# %%
df_trans_Q4_merged = df_trans_Q4_merged.drop(['avg_transaction_amt_x', 'avg_transaction_amt_y', 'total_spent_x', 'total_spent_y'], axis=1)
df_trans_Q4_merged
# Out:
#                      last_Q4_spending  avg_transaction_amt  \
# current_account_nbr
# 033o9yHYen3xoz6k             14571.86           473.076471
# 034bM166vNmgLiIA              1207.40           162.670000
# 049sX01uVFhaa0i2             13703.60           798.333000
# 05AfSsd6epxXiK01             38729.78           370.094333
# 05oLsFWaSLYzc5hv              3114.17           112.040000
# ...                               ...                  ...
# zsYIael1LtCzyZNe              6123.16           162.772500
# zwtnyO2BGLGWUf7r              3233.08           233.333333
# zxOqFgWke0qPQZIO               259.88            64.970000
# zyZhjzJwhpOgSvmc              4194.89           192.074167
# zzEuUBBmvGiVnabb             12242.41           627.105000
#
#                      avg_world_transaction_amt
# current_account_nbr
# 033o9yHYen3xoz6k                     46.639714
# 034bM166vNmgLiIA                     37.862632
# 049sX01uVFhaa0i2                     45.398968
# 05AfSsd6epxXiK01                     76.500556
# 05oLsFWaSLYzc5hv                     58.224667
# ...                                        ...
# zsYIael1LtCzyZNe                     44.729429
# zwtnyO2BGLGWUf7r                     70.363333
# zxOqFgWke0qPQZIO                      0.000000
# zyZhjzJwhpOgSvmc                     30.983607
# zzEuUBBmvGiVnabb                     86.541449
#
# [4192 rows x 3 columns]

# %% [markdown]
# ## Combining with Account Features Data

# %% [markdown]
# Needed columns: cu_card_line, cu_bhv_scr, cu_nbr_days_dlq, ca_avg_utilz_lst_6_mnths, ca_nsf_count_lst_12_months, cu_otb, rb_new_bhv_scr, ca_avg_utilz_lst_3_mnths

# %%
col_keep = ['cu_crd_line', 'current_account_nbr', 'cu_bhv_scr', 'cu_nbr_days_dlq', 'ca_avg_utilz_lst_6_mnths', 'ca_nsf_count_lst_12_months', 'cu_otb', 'rb_new_bhv_scr', 'ca_avg_utilz_lst_3_mnths', 'ca_max_dlq_lst_6_mnths', 'cu_processing_date']

# %%
df_rams_clean = df_rams[col_keep]
df_rams_clean
# Out:
#        cu_crd_line current_account_nbr  cu_bhv_scr  cu_nbr_days_dlq  \
# 0            25000    37eHiwRArQ0A7jhs         779                0
# 1             1500    UV2Z1ODsmodPM2eO         735                0
# 2            40000    VqweW0TxF93M2EF5         745                0
# 3              300    pfKs8HDpmFV3b1zL          13                0
# 4             5200    35VRb2UTGapQk6wE           6                0
# ...            ...                 ...         ...              ...
# 96794          900    Qc7bVxgbL7yLnwHk           6               30
# 96795         6700    HaSj4cm2eeV1ddau         709                0
# 96796        16600    TUgAUpJzGvRCZPhr         755                0
# 96797         4000    dCC3ETrdP8KNK5dM         748                0
# 96798         2550    hQXaPLagczxxH5Ea         752                0
#
#        ca_avg_utilz_lst_6_mnths  ca_nsf_count_lst_12_months    cu_otb  \
# 0                             2                           0  24002.44
# 1                             2                           0   1500.00
# 2                             2                           0  38982.45
# 3                             0                           0    300.00
# 4                             7                           0   4368.27
# ...                         ...                         ...       ...
# 96794                        15                           0    679.76
# 96795                         8                           0   6230.00
# 96796                         5                           0  15562.17
# 96797                         0                           0   4000.00
# 96798                         0                           0   2550.00
#
#        rb_new_bhv_scr  ca_avg_utilz_lst_3_mnths  ca_max_dlq_lst_6_mnths  \
# 0                 776                         2                       0
# 1                 735                         0                       0
# 2                 748                         1                       0
# 3                  13                         0                       0
# 4                   6                         7                       0
# ...               ...                       ...                     ...
# 96794             628                        15                       1
# 96795             703                         7                       0
# 96796             761                         5                       0
# 96797             748                         0                       0
# 96798              13                         0                       0
#
#       cu_processing_date
# 0             2024-12-17
# 1             2025-02-21
# 2             2024-10-10
# 3             2025-01-27
# 4             2025-03-19
# ...                  ...
# 96794         2024-11-14
# 96795         2025-02-27
# 96796         2025-01-24
# 96797         2025-02-20
# 96798         2025-03-21
#
# [96799 rows x 11 columns]

# %%
df_rams_sorted = df_rams_clean.sort_values(by='current_account_nbr')
df_rams_sorted
# Out:
#        cu_crd_line current_account_nbr  cu_bhv_scr  cu_nbr_days_dlq  \
# 36973         3500    00iP5U82D8XwVQ9G         742                0
# 6623          3500    00iP5U82D8XwVQ9G         735                0
# 91888         3500    00iP5U82D8XwVQ9G         735                0
# 13493         3500    00iP5U82D8XwVQ9G         744                0
# 31420         3500    00iP5U82D8XwVQ9G         738                0
# ...            ...                 ...         ...              ...
# 51612         9900    zzztTVczEiGgAEJi          13                0
# 15565         9900    zzztTVczEiGgAEJi          13                0
# 13117         9900    zzztTVczEiGgAEJi          13                0
# 25254         9900    zzztTVczEiGgAEJi          13                0
# 33255         9900    zzztTVczEiGgAEJi          13                0
#
#        ca_avg_utilz_lst_6_mnths  ca_nsf_count_lst_12_months   cu_otb  \
# 36973                        11                           0  2980.80
# 6623                         14                           0  3005.81
# 91888                        14                           0  3165.90
# 13493                        12                           0  2863.99
# 31420                        12                           0  2818.14
# ...                         ...                         ...      ...
# 51612                         0                           0  9900.00
# 15565                         0                           0  9900.00
# 13117                         0                           0  9900.00
# 25254                         0                           0  9900.00
# 33255                         0                           0  9900.00
#
#        rb_new_bhv_scr  ca_avg_utilz_lst_3_mnths  ca_max_dlq_lst_6_mnths  \
# 36973             744                        11                       0
# 6623              735                        17                       0
# 91888             742                        14                       0
# 13493             738                        15                       0
# 31420             735                        17                       0
# ...               ...                       ...                     ...
# 51612              13                         0                       0
# 15565              13                         0                       0
# 13117              13                         0                       0
# 25254              13                         0                       0
# 33255              13                         0                       0
#
#       cu_processing_date
# 36973         2024-10-25
# 6623          2025-01-26
# 91888         2025-02-23
# 13493         2024-11-25
# 31420         2024-12-26
# ...                  ...
# 51612         2024-11-27
# 15565         2024-10-28
# 13117         2025-01-28
# 25254         2024-12-27
# 33255         2024-09-27
#
# [96799 rows x 11 columns]

# %%
df_rams_sorted['cu_processing_date'] = pd.to_datetime(df_rams_sorted['cu_processing_date'])

# %%
df_rams_recent = df_rams_sorted.loc[df_rams_sorted.groupby('current_account_nbr')['cu_processing_date'].idxmax()]
df_rams_recent
# Out:
#        cu_crd_line current_account_nbr  cu_bhv_scr  cu_nbr_days_dlq  \
# 91888         3500    00iP5U82D8XwVQ9G         735                0
# 78527         2900    00oyr3QppAzjLws4         661                0
# 18577         1750    01SEhQXHbPJRc1Go          12                0
# 40876          400    01wbqz3obYPYxLvR          11                0
# 32410         2000    020qpQKv0isIguXC          12                0
# ...            ...                 ...         ...              ...
# 28670        14800    zzBy2qNM78aRV580         749                0
# 37689         6000    zzEuUBBmvGiVnabb         724                0
# 73832         5000    zzR9PvG7dY9u5iHU           6                0
# 25724         1000    zzXGgGu6ysGwGH1J           0                0
# 49542         9900    zzztTVczEiGgAEJi          13                0
#
#        ca_avg_utilz_lst_6_mnths  ca_nsf_count_lst_12_months    cu_otb  \
# 91888                        14                           0   3165.90
# 78527                        90                           0    367.58
# 18577                         0                           0   1750.00
# 40876                         0                           0    400.00
# 32410                         0                           0   2000.00
# ...                         ...                         ...       ...
# 28670                         1                           0  14800.00
# 37689                        15                           0   5212.50
# 73832                         9                           0   4179.62
# 25724                         0                           0   1000.00
# 49542                         0                           0   9900.00
#
#        rb_new_bhv_scr  ca_avg_utilz_lst_3_mnths  ca_max_dlq_lst_6_mnths  \
# 91888             742                        14                       0
# 78527             679                        90                       0
# 18577              12                         0                       0
# 40876              11                         0                       0
# 32410              12                         0                       0
# ...               ...                       ...                     ...
# 28670             746                         0                       0
# 37689             752                        20                       0
# 73832               6                         9                       0
# 25724               6                         0                       0
# 49542              13                         0                       0
#
#       cu_processing_date
# 91888         2025-02-23
# 78527         2025-03-10
# 18577         2025-02-27
# 40876         2025-03-13
# 32410         2025-03-23
# ...                  ...
# 28670         2025-03-23
# 37689         2025-03-04
# 73832         2025-03-19
# 25724         2025-03-12
# 49542         2025-02-25
#
# [17569 rows x 11 columns]

# %%
df_rams_recent = df_rams_recent.reset_index(drop=True)

# %% [markdown]
# ## Adding New Variables

# %% [markdown]
# ### Thoughts:
#
#  - Higher OTB means they still have more money to spend, possibly indiciating that they will spend more in Q4
#  - If spending increases throughout Q1 - Q3, spending might continue to increase in Q4
#  - Higher current credit line means more money to spend

# %%
df_predict_Q4 = pd.merge(df_total_trans_Q1_to_Q3, df_rams_recent, on="current_account_nbr")
df_predict_Q4
# Out:
#      current_account_nbr  avg_trans_Q1_x  avg_trans_Q2_x  avg_trans_Q3_x  \
# 0       033o9yHYen3xoz6k     1252.330000      306.939375      414.374615
# 1       05AfSsd6epxXiK01       34.202500      383.900909      383.521064
# 2       05oLsFWaSLYzc5hv       45.220000      214.815000      106.415652
# 3       062wBe4JtO4ij7Mp       60.830000      412.893514      536.998750
# 4       06SijOFpCXUvw9hs     2450.985000      555.494583      239.558800
# ...                  ...             ...             ...             ...
# 1494    znzcg2AkVtchRVjt       35.355000      190.928276      203.155926
# 1495    zoBLVNjS9F2gDeYk       57.285000      507.469524     1049.958158
# 1496    zoD9wnDwZFJyCtcj      651.920000      132.946842      167.346667
# 1497    zsYIael1LtCzyZNe       21.582857      219.210400      180.819474
# 1498    zzEuUBBmvGiVnabb      271.130000      322.727143      285.767273
#
#       avg_trans_Q1_y  avg_trans_Q2_y  avg_trans_Q3_y  total_Q1  total_Q2  \
# 0          32.135000       41.522842       48.115600   1380.87   8855.70
# 1          29.842083       62.658500      110.187923    853.02  29423.34
# 2          12.283333       23.003400       17.663810    209.36   5737.38
# 3          70.965000       67.182686       85.497172   1317.93  27034.03
# 4          49.036154      153.990196       45.690706   5539.44  21185.37
# ...              ...             ...             ...       ...       ...
# 1494       91.596667       57.197442       70.747222    345.50   7996.41
# 1495       29.103750       97.974510       56.514945    813.06  51293.92
# 1496       13.318000       20.744333       16.279703    718.51   4392.98
# 1497       37.055000      151.780000       56.985263    447.52   8515.86
# 1498      145.112500       76.902750       64.490256   1122.71   7594.29
#
#       total_Q3  cu_crd_line  cu_bhv_scr  cu_nbr_days_dlq  \
# 0     10198.43        15000         747                0
# 1     38189.88        15000         740                0
# 2      3931.32        15000         774                0
# 3     29581.05        25000         753                0
# 4      9872.68        25000         751                0
# ...        ...          ...         ...              ...
# 1494   8032.11        15000         755                0
# 1495  60469.85        25000         752                0
# 1496   5158.53        12800         760                0
# 1497   4518.29        14700         688                0
# 1498   5658.56         6000         724                0
#
#       ca_avg_utilz_lst_6_mnths  ca_nsf_count_lst_12_months    cu_otb  \
# 0                           15                           0  12599.88
# 1                           39                           0  11494.90
# 2                            2                           0  14881.28
# 3                           13                           0  22154.83
# 4                           11                           0  22454.40
# ...                        ...                         ...       ...
# 1494                        10                           0  13210.05
# 1495                        20                           0  18325.42
# 1496                         6                           0  11925.54
# 1497                        91                           0   1183.89
# 1498                        15                           0   5212.50
#
#       rb_new_bhv_scr  ca_avg_utilz_lst_3_mnths  ca_max_dlq_lst_6_mnths  \
# 0                744                        14                       0
# 1                740                        35                       0
# 2                774                         0                       0
# 3                752                        12                       0
# 4                754                        12                       0
# ...              ...                       ...                     ...
# 1494             755                        11                       0
# 1495             730                        16                       0
# 1496             760                         6                       0
# 1497             694                        92                       0
# 1498             752                        20                       0
#
#      cu_processing_date
# 0            2025-03-10
# 1            2025-02-27
# 2            2025-02-25
# 3            2025-02-23
# 4            2025-03-16
# ...                 ...
# 1494         2025-02-26
# 1495         2025-03-21
# 1496         2025-03-21
# 1497         2025-03-13
# 1498         2025-03-04
#
# [1499 rows x 20 columns]

# %%
df_predict_Q4 = pd.merge(df_predict_Q4, df_trans_Q4_merged, on="current_account_nbr")
df_predict_Q4
# Out:
#      current_account_nbr  avg_trans_Q1_x  avg_trans_Q2_x  avg_trans_Q3_x  \
# 0       033o9yHYen3xoz6k     1252.330000      306.939375      414.374615
# 1       05AfSsd6epxXiK01       34.202500      383.900909      383.521064
# 2       05oLsFWaSLYzc5hv       45.220000      214.815000      106.415652
# 3       062wBe4JtO4ij7Mp       60.830000      412.893514      536.998750
# 4       06SijOFpCXUvw9hs     2450.985000      555.494583      239.558800
# ...                  ...             ...             ...             ...
# 1481    znzcg2AkVtchRVjt       35.355000      190.928276      203.155926
# 1482    zoBLVNjS9F2gDeYk       57.285000      507.469524     1049.958158
# 1483    zoD9wnDwZFJyCtcj      651.920000      132.946842      167.346667
# 1484    zsYIael1LtCzyZNe       21.582857      219.210400      180.819474
# 1485    zzEuUBBmvGiVnabb      271.130000      322.727143      285.767273
#
#       avg_trans_Q1_y  avg_trans_Q2_y  avg_trans_Q3_y  total_Q1  total_Q2  \
# 0          32.135000       41.522842       48.115600   1380.87   8855.70
# 1          29.842083       62.658500      110.187923    853.02  29423.34
# 2          12.283333       23.003400       17.663810    209.36   5737.38
# 3          70.965000       67.182686       85.497172   1317.93  27034.03
# 4          49.036154      153.990196       45.690706   5539.44  21185.37
# ...              ...             ...             ...       ...       ...
# 1481       91.596667       57.197442       70.747222    345.50   7996.41
# 1482       29.103750       97.974510       56.514945    813.06  51293.92
# 1483       13.318000       20.744333       16.279703    718.51   4392.98
# 1484       37.055000      151.780000       56.985263    447.52   8515.86
# 1485      145.112500       76.902750       64.490256   1122.71   7594.29
#
#       total_Q3  ...  ca_avg_utilz_lst_6_mnths  ca_nsf_count_lst_12_months  \
# 0     10198.43  ...                        15                           0
# 1     38189.88  ...                        39                           0
# 2      3931.32  ...                         2                           0
# 3     29581.05  ...                        13                           0
# 4      9872.68  ...                        11                           0
# ...        ...  ...                       ...                         ...
# 1481   8032.11  ...                        10                           0
# 1482  60469.85  ...                        20                           0
# 1483   5158.53  ...                         6                           0
# 1484   4518.29  ...                        91                           0
# 1485   5658.56  ...                        15                           0
#
#         cu_otb  rb_new_bhv_scr  ca_avg_utilz_lst_3_mnths  \
# 0     12599.88             744                        14
# 1     11494.90             740                        35
# 2     14881.28             774                         0
# 3     22154.83             752                        12
# 4     22454.40             754                        12
# ...        ...             ...                       ...
# 1481  13210.05             755                        11
# 1482  18325.42             730                        16
# 1483  11925.54             760                         6
# 1484   1183.89             694                        92
# 1485   5212.50             752                        20
#
#       ca_max_dlq_lst_6_mnths  cu_processing_date  last_Q4_spending  \
# 0                          0          2025-03-10          14571.86
# 1                          0          2025-02-27          38729.78
# 2                          0          2025-02-25           3114.17
# 3                          0          2025-02-23          23003.63
# 4                          0          2025-03-16          12370.50
# ...                      ...                 ...               ...
# 1481                       0          2025-02-26           9306.84
# 1482                       0          2025-03-21          34958.43
# 1483                       0          2025-03-21           4307.47
# 1484                       0          2025-03-13           6123.16
# 1485                       0          2025-03-04          12242.41
#
#       avg_transaction_amt avg_world_transaction_amt
# 0              473.076471                 46.639714
# 1              370.094333                 76.500556
# 2              112.040000                 58.224667
# 3              294.223721                 61.254497
# 4              239.384815                 46.149297
# ...                   ...                       ...
# 1481           185.269375                 47.580563
# 1482           415.649762                 60.348759
# 1483           120.189231                 12.715591
# 1484           162.772500                 44.729429
# 1485           627.105000                 86.541449
#
# [1486 rows x 23 columns]

# %%
cols_predict = ['total_Q1', 'total_Q2', 'total_Q3', 'last_Q4_spending', 'cu_crd_line', 'cu_otb', 'cu_bhv_scr', 'rb_new_bhv_scr', 'ca_avg_utilz_lst_6_mnths', 'ca_nsf_count_lst_12_months', 'ca_avg_utilz_lst_3_mnths', 'ca_max_dlq_lst_6_mnths']

# %%
df_predict_Q4 = df_predict_Q4[cols_predict]
df_predict_Q4
# Out:
#       total_Q1  total_Q2  total_Q3  last_Q4_spending  cu_crd_line    cu_otb  \
# 0      1380.87   8855.70  10198.43          14571.86        15000  12599.88
# 1       853.02  29423.34  38189.88          38729.78        15000  11494.90
# 2       209.36   5737.38   3931.32           3114.17        15000  14881.28
# 3      1317.93  27034.03  29581.05          23003.63        25000  22154.83
# 4      5539.44  21185.37   9872.68          12370.50        25000  22454.40
# ...        ...       ...       ...               ...          ...       ...
# 1481    345.50   7996.41   8032.11           9306.84        15000  13210.05
# 1482    813.06  51293.92  60469.85          34958.43        25000  18325.42
# 1483    718.51   4392.98   5158.53           4307.47        12800  11925.54
# 1484    447.52   8515.86   4518.29           6123.16        14700   1183.89
# 1485   1122.71   7594.29   5658.56          12242.41         6000   5212.50
#
#       cu_bhv_scr  rb_new_bhv_scr  ca_avg_utilz_lst_6_mnths  \
# 0            747             744                        15
# 1            740             740                        39
# 2            774             774                         2
# 3            753             752                        13
# 4            751             754                        11
# ...          ...             ...                       ...
# 1481         755             755                        10
# 1482         752             730                        20
# 1483         760             760                         6
# 1484         688             694                        91
# 1485         724             752                        15
#
#       ca_nsf_count_lst_12_months  ca_avg_utilz_lst_3_mnths  \
# 0                              0                        14
# 1                              0                        35
# 2                              0                         0
# 3                              0                        12
# 4                              0                        12
# ...                          ...                       ...
# 1481                           0                        11
# 1482                           0                        16
# 1483                           0                         6
# 1484                           0                        92
# 1485                           0                        20
#
#       ca_max_dlq_lst_6_mnths
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# 4                          0
# ...                      ...
# 1481                       0
# 1482                       0
# 1483                       0
# 1484                       0
# 1485                       0
#
# [1486 rows x 12 columns]

# %% [markdown]
# ## Finding Correlation

# %%
df_predict_Q4.corr(method="pearson")
# Out:
#                             total_Q1  total_Q2  total_Q3  last_Q4_spending  \
# total_Q1                    1.000000  0.390531  0.378311          0.340146
# total_Q2                    0.390531  1.000000  0.827516          0.768182
# total_Q3                    0.378311  0.827516  1.000000          0.813836
# last_Q4_spending            0.340146  0.768182  0.813836          1.000000
# cu_crd_line                 0.101569  0.263622  0.264769          0.265325
# cu_otb                      0.021213  0.074279  0.071633          0.077028
# cu_bhv_scr                 -0.096426 -0.109660 -0.126868         -0.101478
# rb_new_bhv_scr             -0.077111 -0.080075 -0.091822         -0.077039
# ca_avg_utilz_lst_6_mnths    0.110776  0.205253  0.228794          0.227659
# ca_nsf_count_lst_12_months -0.012458  0.006901  0.008749          0.011237
# ca_avg_utilz_lst_3_mnths    0.093485  0.191892  0.206310          0.180513
# ca_max_dlq_lst_6_mnths      0.078399 -0.036731 -0.048239         -0.066507
#
#                             cu_crd_line    cu_otb  cu_bhv_scr  rb_new_bhv_scr  \
# total_Q1                       0.101569  0.021213   -0.096426       -0.077111
# total_Q2                       0.263622  0.074279   -0.109660       -0.080075
# total_Q3                       0.264769  0.071633   -0.126868       -0.091822
# last_Q4_spending               0.265325  0.077028   -0.101478       -0.077039
# cu_crd_line                    1.000000  0.848217    0.189103        0.186281
# cu_otb                         0.848217  1.000000    0.392262        0.395129
# cu_bhv_scr                     0.189103  0.392262    1.000000        0.780015
# rb_new_bhv_scr                 0.186281  0.395129    0.780015        1.000000
# ca_avg_utilz_lst_6_mnths      -0.211102 -0.574210   -0.621218       -0.507820
# ca_nsf_count_lst_12_months     0.024689  0.030826    0.008492        0.016123
# ca_avg_utilz_lst_3_mnths      -0.196079 -0.588058   -0.613154       -0.507515
# ca_max_dlq_lst_6_mnths        -0.066676 -0.095212   -0.168894       -0.159835
#
#                             ca_avg_utilz_lst_6_mnths  \
# total_Q1                                    0.110776
# total_Q2                                    0.205253
# total_Q3                                    0.228794
# last_Q4_spending                            0.227659
# cu_crd_line                                -0.211102
# cu_otb                                     -0.574210
# cu_bhv_scr                                 -0.621218
# rb_new_bhv_scr                             -0.507820
# ca_avg_utilz_lst_6_mnths                    1.000000
# ca_nsf_count_lst_12_months                 -0.016506
# ca_avg_utilz_lst_3_mnths                    0.963405
# ca_max_dlq_lst_6_mnths                      0.105441
#
#                             ca_nsf_count_lst_12_months  \
# total_Q1                                     -0.012458
# total_Q2                                      0.006901
# total_Q3                                      0.008749
# last_Q4_spending                              0.011237
# cu_crd_line                                   0.024689
# cu_otb                                        0.030826
# cu_bhv_scr                                    0.008492
# rb_new_bhv_scr                                0.016123
# ca_avg_utilz_lst_6_mnths                     -0.016506
# ca_nsf_count_lst_12_months                    1.000000
# ca_avg_utilz_lst_3_mnths                     -0.013267
# ca_max_dlq_lst_6_mnths                       -0.013607
#
#                             ca_avg_utilz_lst_3_mnths  ca_max_dlq_lst_6_mnths
# total_Q1                                    0.093485                0.078399
# total_Q2                                    0.191892               -0.036731
# total_Q3                                    0.206310               -0.048239
# last_Q4_spending                            0.180513               -0.066507
# cu_crd_line                                -0.196079               -0.066676
# cu_otb                                     -0.588058               -0.095212
# cu_bhv_scr                                 -0.613154               -0.168894
# rb_new_bhv_scr                             -0.507515               -0.159835
# ca_avg_utilz_lst_6_mnths                    0.963405                0.105441
# ca_nsf_count_lst_12_months                 -0.013267               -0.013607
# ca_avg_utilz_lst_3_mnths                    1.000000                0.112088
# ca_max_dlq_lst_6_mnths                      0.112088                1.000000

# %% [markdown]
# ## Making Models

# %%
model_Q2 = smf.ols("total_Q2 ~ total_Q1 + cu_crd_line + ca_avg_utilz_lst_6_mnths", data = df_predict_Q4).fit()
model_Q2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               total_Q2   R-squared:                       0.251
# Model:                            OLS   Adj. R-squared:                  0.250
# Method:                 Least Squares   F-statistic:                     165.8
# Date:                Sat, 29 Mar 2025   Prob (F-statistic):           1.17e-92
# Time:                        18:11:41   Log-Likelihood:                -16072.
# No. Observations:                1486   AIC:                         3.215e+04
# Df Residuals:                    1482   BIC:                         3.217e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                 -529.9154   1145.139     -0.463      0.644   -2776.181    1716.350
# total_Q1                     2.2399      0.151     14.790      0.000       1.943       2.537
# cu_crd_line                  0.7415      0.062     11.953      0.000       0.620       0.863
# ca_avg_utilz_lst_6_mnths   176.5857     18.104      9.754      0.000     141.073     212.098
# ==============================================================================
# Omnibus:                     1083.674   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            38459.831
# Skew:                           2.975   Prob(JB):                         0.00
# Kurtosis:                      27.202   Cond. No.                     6.20e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.2e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model_Q3 = smf.ols("total_Q3 ~ total_Q1 + total_Q2 + cu_crd_line + ca_avg_utilz_lst_6_mnths", data = df_predict_Q4).fit()
model_Q3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               total_Q3   R-squared:                       0.696
# Model:                            OLS   Adj. R-squared:                  0.695
# Method:                 Least Squares   F-statistic:                     848.9
# Date:                Sat, 29 Mar 2025   Prob (F-statistic):               0.00
# Time:                        18:11:41   Log-Likelihood:                -15346.
# No. Observations:                1486   AIC:                         3.070e+04
# Df Residuals:                    1481   BIC:                         3.073e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                 -572.3951    702.763     -0.814      0.415   -1950.913     806.122
# total_Q1                     0.3985      0.100      4.003      0.000       0.203       0.594
# total_Q2                     0.7394      0.016     46.384      0.000       0.708       0.771
# cu_crd_line                  0.1879      0.040      4.714      0.000       0.110       0.266
# ca_avg_utilz_lst_6_mnths    59.9042     11.461      5.227      0.000      37.423      82.385
# ==============================================================================
# Omnibus:                      268.623   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4389.981
# Skew:                           0.321   Prob(JB):                         0.00
# Kurtosis:                      11.396   Cond. No.                     9.82e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.82e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model_Q4 = smf.ols("last_Q4_spending ~ total_Q1 + total_Q2 + total_Q3 + cu_crd_line + ca_avg_utilz_lst_6_mnths", data = df_predict_Q4).fit()
model_Q4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       last_Q4_spending   R-squared:                       0.695
# Model:                            OLS   Adj. R-squared:                  0.694
# Method:                 Least Squares   F-statistic:                     674.2
# Date:                Sat, 29 Mar 2025   Prob (F-statistic):               0.00
# Time:                        18:11:41   Log-Likelihood:                -15394.
# No. Observations:                1486   AIC:                         3.080e+04
# Df Residuals:                    1480   BIC:                         3.083e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                 -571.2733    726.275     -0.787      0.432   -1995.911     853.364
# total_Q1                     0.0661      0.103      0.639      0.523      -0.137       0.269
# total_Q2                     0.2853      0.026     11.059      0.000       0.235       0.336
# total_Q3                     0.5616      0.027     20.917      0.000       0.509       0.614
# cu_crd_line                  0.1482      0.041      3.571      0.000       0.067       0.230
# ca_avg_utilz_lst_6_mnths    42.3197     11.950      3.541      0.000      18.879      65.761
# ==============================================================================
# Omnibus:                      622.301   Durbin-Watson:                   2.164
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            21969.641
# Skew:                           1.281   Prob(JB):                         0.00
# Kurtosis:                      21.662   Cond. No.                     1.24e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.24e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## Getting Q1 2025

# %%
df_transactions_Q125 = df_transactions_clean[df_transactions_clean["transaction_date"].astype(str).str.startswith(("2025-01", "2025-02", "2025-03"))]
df_transactions_Q125
# Out:
#        current_account_nbr transaction_type  transaction_code  \
# 7         CMwVNwFlQtZ6lcWW             SALE               253
# 8         0AqLx6QcUKlxYVnf             SALE               253
# 9         cxK13NgvQWKwsdNH          PAYMENT               271
# 10        0jk6WnqyQZIo0Bz8             SALE               253
# 24        zhCQqBwTIUIFHnFH             SALE               253
# ...                    ...              ...               ...
# 493330    xWPY5ARVAZvYDFOB          PAYMENT               271
# 493331    ktpdvlbVRuywp2Po             SALE               253
# 493333    zp60CmOQNComnHDT             SALE               253
# 493334    8M5fnshTsgW9mW8Y          PAYMENT               271
# 493335    qT645tAyt7uDVJtL           RETURN               255
#
#        transaction_date  transaction_amt  payment_type  \
# 7            2025-02-02            70.78           NaN
# 8            2025-02-14           158.97           NaN
# 9            2025-03-11           200.00           NaN
# 10           2025-03-16           397.59           NaN
# 24           2025-02-09            35.31           NaN
# ...                 ...              ...           ...
# 493330       2025-02-04           300.00           NaN
# 493331       2025-03-07             3.99           NaN
# 493333       2025-02-04            15.62           NaN
# 493334       2025-02-05           100.00           NaN
# 493335       2025-02-14            44.14           NaN
#
#         transaction_return_cnt  transaction_sale_cnt
# 7                            0                     1
# 8                            0                     1
# 9                            0                     0
# 10                           0                     1
# 24                           0                     1
# ...                        ...                   ...
# 493330                       0                     0
# 493331                       0                     1
# 493333                       0                     1
# 493334                       0                     0
# 493335                       1                     0
#
# [115094 rows x 8 columns]

# %%
df_world_trans_Q125 = df_world_trans_clean[df_world_trans_clean["transaction_date"].astype(str).str.startswith(("2025-01", "2025-02", "2025-03"))]
df_world_trans_Q125
# Out:
#         current_account_nbr transaction_type  transaction_code  \
# 6          ZTDQXJK90HWr8Qci             SALE               253
# 7          SVLTisn540exAh2Y             SALE               253
# 8          wQ2hfsT6Yb3svYu1             SALE               253
# 18         ACScbBW7kMRJy2L2             SALE               253
# 19         yV4tmHrHgEsgJkWb             SALE               253
# ...                     ...              ...               ...
# 1053845    UCQDQq1PQEQicEll             SALE               253
# 1053846    hTefCbHhFcf4yeoi             SALE               253
# 1053848    RHjoQGhTFr6YvM5Z             SALE               253
# 1053850    ZGjYc8aETjtytUYR             SALE               253
# 1053851    4JpGONAzyfmoxi7A             SALE               253
#
#         transaction_date  transaction_amt  payment_type  \
# 6             2025-01-19             5.07           NaN
# 7             2025-01-23            52.00           NaN
# 8             2025-02-11            10.00           NaN
# 18            2025-01-10             7.80           NaN
# 19            2025-01-30             9.70           NaN
# ...                  ...              ...           ...
# 1053845       2025-02-08            32.57           NaN
# 1053846       2025-02-20             5.04           NaN
# 1053848       2025-03-03            99.00           NaN
# 1053850       2025-03-10            16.11           NaN
# 1053851       2025-03-20            20.37           NaN
#
#          transaction_return_cnt  transaction_sale_cnt
# 6                             0                     1
# 7                             0                     1
# 8                             0                     1
# 18                            0                     1
# 19                            0                     1
# ...                         ...                   ...
# 1053845                       0                     1
# 1053846                       0                     1
# 1053848                       0                     1
# 1053850                       0                     1
# 1053851                       0                     1
#
# [245070 rows x 8 columns]

# %%
df_transactions_Q125_sum = df_transactions_Q125.groupby("current_account_nbr").agg(
    total_spent = ("transaction_amt", "sum"),
    avg_transaction_amt = ("transaction_amt", "mean")
)
df_transactions_Q125_sum
# Out:
#                      total_spent  avg_transaction_amt
# current_account_nbr
# 00gwujJkd597VxLd           25.90            25.900000
# 00iP5U82D8XwVQ9G         2714.50            16.653374
# 00oyr3QppAzjLws4          484.30            80.716667
# 02WRVV8yusgcZWLW        10440.58          1044.058000
# 033o9yHYen3xoz6k         5124.36           320.272500
# ...                          ...                  ...
# zyZhjzJwhpOgSvmc         1632.96           233.280000
# zz3nbtZXS41NZk0h          215.99            53.997500
# zzBy2qNM78aRV580          440.00           220.000000
# zzEuUBBmvGiVnabb         6091.38           609.138000
# zzR9PvG7dY9u5iHU         1043.38           260.845000
#
# [11541 rows x 2 columns]

# %%
df_world_trans_Q125_sum = df_world_trans_Q125.groupby("current_account_nbr").agg(
    total_spent = ("transaction_amt", "sum"),
    avg_transaction_amt = ("transaction_amt", "mean")
)
df_world_trans_Q125_sum
# Out:
#                      total_spent  avg_transaction_amt
# current_account_nbr
# 02WRVV8yusgcZWLW         6503.30           103.226984
# 033o9yHYen3xoz6k         5997.06            50.822542
# 034bM166vNmgLiIA          221.24            24.582222
# 049sX01uVFhaa0i2         6415.82            50.123594
# 05AfSsd6epxXiK01         6592.47            59.931545
# ...                          ...                  ...
# zuPY0iifqZT124F8          210.00            70.000000
# zwtnyO2BGLGWUf7r          637.17            49.013077
# zxOqFgWke0qPQZIO            0.00             0.000000
# zyZhjzJwhpOgSvmc         2203.61            25.924824
# zzEuUBBmvGiVnabb         8270.59           153.159074
#
# [4620 rows x 2 columns]

# %%
df_trans_Q125_merged = pd.merge(df_transactions_Q125_sum, df_world_trans_Q125_sum, on="current_account_nbr")
df_trans_Q125_merged
# Out:
#                      total_spent_x  avg_transaction_amt_x  total_spent_y  \
# current_account_nbr
# 02WRVV8yusgcZWLW          10440.58            1044.058000        6503.30
# 033o9yHYen3xoz6k           5124.36             320.272500        5997.06
# 034bM166vNmgLiIA            200.00             100.000000         221.24
# 049sX01uVFhaa0i2           6404.95             800.618750        6415.82
# 05AfSsd6epxXiK01          17934.55             498.181944        6592.47
# ...                            ...                    ...            ...
# zsYIael1LtCzyZNe           4314.88             392.261818         420.80
# zwtnyO2BGLGWUf7r           5617.66            1872.553333         637.17
# zxOqFgWke0qPQZIO            383.58             191.790000           0.00
# zyZhjzJwhpOgSvmc           1632.96             233.280000        2203.61
# zzEuUBBmvGiVnabb           6091.38             609.138000        8270.59
#
#                      avg_transaction_amt_y
# current_account_nbr
# 02WRVV8yusgcZWLW                103.226984
# 033o9yHYen3xoz6k                 50.822542
# 034bM166vNmgLiIA                 24.582222
# 049sX01uVFhaa0i2                 50.123594
# 05AfSsd6epxXiK01                 59.931545
# ...                                    ...
# zsYIael1LtCzyZNe                 24.752941
# zwtnyO2BGLGWUf7r                 49.013077
# zxOqFgWke0qPQZIO                  0.000000
# zyZhjzJwhpOgSvmc                 25.924824
# zzEuUBBmvGiVnabb                153.159074
#
# [4398 rows x 4 columns]

# %%
df_trans_Q125_merged["total_Q125"] = df_trans_Q125_merged["total_spent_x"] + df_trans_Q125_merged["total_spent_y"]
df_trans_Q125_merged
# Out:
#                      total_spent_x  avg_transaction_amt_x  total_spent_y  \
# current_account_nbr
# 02WRVV8yusgcZWLW          10440.58            1044.058000        6503.30
# 033o9yHYen3xoz6k           5124.36             320.272500        5997.06
# 034bM166vNmgLiIA            200.00             100.000000         221.24
# 049sX01uVFhaa0i2           6404.95             800.618750        6415.82
# 05AfSsd6epxXiK01          17934.55             498.181944        6592.47
# ...                            ...                    ...            ...
# zsYIael1LtCzyZNe           4314.88             392.261818         420.80
# zwtnyO2BGLGWUf7r           5617.66            1872.553333         637.17
# zxOqFgWke0qPQZIO            383.58             191.790000           0.00
# zyZhjzJwhpOgSvmc           1632.96             233.280000        2203.61
# zzEuUBBmvGiVnabb           6091.38             609.138000        8270.59
#
#                      avg_transaction_amt_y  total_Q125
# current_account_nbr
# 02WRVV8yusgcZWLW                103.226984    16943.88
# 033o9yHYen3xoz6k                 50.822542    11121.42
# 034bM166vNmgLiIA                 24.582222      421.24
# 049sX01uVFhaa0i2                 50.123594    12820.77
# 05AfSsd6epxXiK01                 59.931545    24527.02
# ...                                    ...         ...
# zsYIael1LtCzyZNe                 24.752941     4735.68
# zwtnyO2BGLGWUf7r                 49.013077     6254.83
# zxOqFgWke0qPQZIO                  0.000000      383.58
# zyZhjzJwhpOgSvmc                 25.924824     3836.57
# zzEuUBBmvGiVnabb                153.159074    14361.97
#
# [4398 rows x 5 columns]

# %%
df_trans_Q125_merged = df_trans_Q125_merged.drop(['total_spent_x', 'total_spent_y', 'avg_transaction_amt_x', 'avg_transaction_amt_y'], axis=1)
df_trans_Q125_merged
# Out:
#                      total_Q125
# current_account_nbr
# 02WRVV8yusgcZWLW       16943.88
# 033o9yHYen3xoz6k       11121.42
# 034bM166vNmgLiIA         421.24
# 049sX01uVFhaa0i2       12820.77
# 05AfSsd6epxXiK01       24527.02
# ...                         ...
# zsYIael1LtCzyZNe        4735.68
# zwtnyO2BGLGWUf7r        6254.83
# zxOqFgWke0qPQZIO         383.58
# zyZhjzJwhpOgSvmc        3836.57
# zzEuUBBmvGiVnabb       14361.97
#
# [4398 rows x 1 columns]

# %%
def predict_Q2(Q1, credit_line, util_6):
    Q2_spending = -529.9154 + 2.2399*Q1 + 0.7415*credit_line + 176.5857*util_6
    return Q2_spending

# %%
def predict_Q3(Q1, Q2, credit_line, util_6):
    Q3_spending = -572.3951 + 0.3985*Q1 + 0.7394*Q2 + 0.1879*credit_line + 59.9042*util_6
    return Q3_spending

# %%
def predict_Q4(Q1, Q2, Q3, credit_line, util_6):
    Q4_spending = -571.2733 + 0.0661*Q1 + 0.2853*Q2 + 0.5616*Q3 + 0.1482*credit_line + 42.3197*util_6
    return Q4_spending
